# %% [markdown]
# # Notebook for Adding NLP Data to Database

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Connect to Database

# %%
import mysql.connector

# %%
endpoint = "seratestdatabase.c4cjk1vto1om.us-east-2.rds.amazonaws.com"
port = "3306"
usr = "admin"
pswd = "your_password_here"
region = "us-east-2b"
dbname = "teachsim"

# %%
cnx = mysql.connector.connect(user=usr, password=pswd, host=endpoint, database=dbname)

# %%
cursor = cnx.cursor(buffered=True)

# %% [markdown]
# ### Test Connection

# %%
cursor.execute("SELECT * FROM Fidelity_Measures;")
result = cursor.fetchall()
colnames = [x[0] for x in cursor.description]
pd.DataFrame(result, columns=colnames)
# Out:
#        doctype                filename             study     model  skill  \
# 0   transcript                   10-2C  Behavior Study 1  behavior    2.0
# 1   transcript                  103-2C  Behavior Study 1  behavior    2.0
# 2   transcript  2019_101_5C_Transcript  Behavior Study 2  behavior    2.0
# 3   transcript  2019_106_5C_Transcript  Behavior Study 2  behavior    2.0
# 4   transcript  2019_119_5C_Transcript  Behavior Study 2  behavior    2.0
# 5   transcript   2019_20_5C_Transcript  Behavior Study 2  behavior    2.0
# 6   transcript   2019_22_5C_Transcript  Behavior Study 2  behavior    2.0
# 7   transcript   2019_34_5C_Transcript  Behavior Study 2  behavior    1.0
# 8   transcript   2019_38_5C_Transcript  Behavior Study 2  behavior    2.0
# 9   transcript   2019_42_5C_Transcript  Behavior Study 2  behavior    2.0
# 10  transcript    2019_5_5C_Transcript  Behavior Study 2  behavior    1.0
# 11  transcript   2019_58_5C_Transcript  Behavior Study 2  behavior    2.0
# 12  transcript   2019_61_5C_Transcript  Behavior Study 2  behavior    3.0
# 13  transcript   2019_66_5C_Transcript  Behavior Study 2  behavior    2.0
# 14  transcript   2019_74_5C_Transcript  Behavior Study 2  behavior    2.0
# 15  transcript   2019_75_5C_Transcript  Behavior Study 2  behavior    3.0
# 16  transcript   2019_81_5C_Transcript  Behavior Study 2  behavior    3.0
# 17  transcript   2019_87_5C_Transcript  Behavior Study 2  behavior    4.0
# 18  transcript   2019_97_5C_Transcript  Behavior Study 2  behavior    3.0
# 19  transcript                    6-2C  Behavior Study 1  behavior    2.0
# 20  transcript                    7-2C  Behavior Study 1  behavior    3.0
# 21  transcript                   72-2C  Behavior Study 1  behavior    4.0
# 22  transcript                   84-2C  Behavior Study 1  behavior    3.0
# 23  transcript                   89-2C  Behavior Study 1  behavior    3.0
# 24  transcript                   93-2C  Behavior Study 1  behavior    4.0
#
#       coach                                               text  \
# 0      None  Okay, so I think that wins. Dont like the simu...
# 1      None  alright. Why dont you have a sit and well-- we...
# 2   person5  Hello. Okay, so how do you think at first run ...
# 3   person3  So tell me how you feel about your first simul...
# 4      None  alright. So, how are you feeling about Okay. W...
# 5   person1  alright, so come on over. How do you feel that...
# 6   person5  Just go ahead and take a seat. Youre fine. You...
# 7   person7  So, how are you feeling about that first ? Tha...
# 8   person7  How are you feeling about the first simulation...
# 9   person3  Aside from terrible, before I tell you my feed...
# 10  person1  Yeah that can be tough. I totally agree. Usual...
# 11  person3  alright. Nice job. Like so many questions for ...
# 12  person3  Go ahead and tell me your thoughts about what ...
# 13  person4   alright, so how do you think that went? What ...
# 14  person4  alright. So firstly, how do you think it went?...
# 15  person4  alright. So, how do you feel about it?  So wha...
# 16  person7  So, how are you feeling about that first simul...
# 17  person3  What do you think you did well? Yeah. So, I no...
# 18  person3  I can tell that youre a little bit frustrated ...
# 19     None  So how do you feel about that? Really hard. Wh...
# 20     None  alright. So how do you think that went? What d...
# 21     None  So how do you feel about that? Yeah? Ethans a ...
# 22     None  So how do you feel about that first run? What ...
# 23     None  alright. So, first of all, how you think that ...
# 24     None  Come on I said   Um, so how are you feeling? H...
#
#                           cleaned_vectorized_document    similarity_score
# 0   [0.5194993709632443, 0.023576768930381554, 0.4...  0.2188967631854828
# 1   [0.4031709161284383, -0.08087668041599247, 0.2...  0.1458457998040087
# 2   [0.5741149744532488, -0.17514627745491707, -0....  0.1962542624321331
# 3   [0.5623479361279925, -0.18734489200306162, -0....  0.2201094467777059
# 4   [0.5764204590246595, -0.03895625224437529, -0....  0.2520476945940342
# 5   [0.6059433028211592, -0.1602070625338875, 0.01...  0.2514485797592812
# 6   [0.604000330114129, -0.06524464897980672, -0.1...  0.2643317150237819
# 7   [0.6361390756591526, -0.04385806229881961, -0....   0.300864457526095
# 8   [0.5822116460450054, -0.01135436117190061, -0....  0.2868702584122339
# 9   [0.5782576176773634, -0.1845167081384388, -0.1...  0.2432368806421148
# 10  [0.6198429304314097, -0.16436602338468467, -0....    0.27062211449407
# 11  [0.5707874299747961, -0.07655687445423678, -0....  0.2773036174463572
# 12  [0.5857308257388976, -0.17879835165872462, -0....  0.2764156744033152
# 13  [0.5562146116395136, 0.041886888940056224, 0.2...   0.277442335294088
# 14  [0.6340172014976612, 0.03390615985090158, 0.15...  0.3368138178999184
# 15  [0.5522985299533579, 0.06468612744392137, 0.15...  0.3231548087311509
# 16  [0.628909629065172, -0.15462315762629905, -0.0...  0.2579052907042272
# 17  [0.5988738638989562, -0.28464286187245935, -0....  0.1863330619207272
# 18  [0.5622812189826345, -0.2423885536669524, -0.2...  0.2222951821350562
# 19  [0.5472509215170646, -0.07767101051949, 0.2492...  0.2444620062278996
# 20  [0.5985432945334412, 0.026909996996568868, 0.5...  0.2687026466867244
# 21  [0.5631591966288553, -0.14461435160156408, 0.2...  0.2354592531487008
# 22  [0.5415378955957224, -0.06078326062310378, 0.3...  0.2721958153445126
# 23  [0.5562795731182689, -0.05180811454241078, 0.4...  0.2314025337276677
# 24  [0.593572612614357, -0.16033280529275065, 0.26...  0.2113657651140333

# %%
cursor.execute("DELETE FROM Fidelity_Measures;")

# %% [markdown]
# ## Functions

# %%
def getColumnNames(tableName, cursor):
    query = "SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = N'" + tableName + "'"
    cursor.execute(query)
    result = cursor.fetchall()
    result2 = [x[0] for x in result]
    
    return result2

# %%
def overlapColumns(cols1, cols2):
    overlap = []
    for col in cols1:
        if col in cols2:
            overlap = overlap + [col]
    return overlap

# %%
def getExistingIds(tableName, cursor):
    query = "SELECT filename FROM " + str(tableName)
    cursor.execute(query)
    result = cursor.fetchall()
    existing_ids = [x[0] for x in result]
    return existing_ids

# %%
def fixStrings(df):
    types = dict(df.dtypes)
    cols = [x for x in df.columns if types[x] == np.object]
    for index, row in df.iterrows():
        for col in cols:
            value = row[col]
            if type(value) == str:
                new = value.replace("'", "")
                new2 = new.replace('"', '')
                df.loc[index, col] = new2
    return df

# %%
def list_queries(df, columns, tableName, existing_ids):
    queries = []
    for index, row in df.iterrows():
        pid = row['filename']
        valid_pid = False
        if type(pid) == str:
            valid_pid = True
                
        # if the row for that participant already exists, just update it
        if pid in existing_ids:
            req_update = False
            query = "UPDATE " + tableName + " SET "
            for col in columns:
                newval = row[col]
                if type(newval) == str:
                    query = query + col + " = '" + newval + "' , "
                    if col != "filename":
                        req_update = True
                elif np.isnan(float(newval)) == False: 
                    query = query + col + " = " + str(newval) + " , "
                    if col != "id_participant":
                        req_update = True
            if req_update == True:
                query = query[:-2]
                query = query + "WHERE filename = '" + row["filename"] + "';"
                queries = queries + [query]
        
        # if that participant is not in the database, create/replace the row
        elif valid_pid == True:
            req_update = False
            query = "REPLACE INTO " +  tableName + " "
            cols = "("
            vals = "("
            for col in columns:
                val = row[col] 
                if type(val) == str:
                    cols = cols + str(col) + ", "
                    vals = vals + "'" + val + "', "
                    if col != "filename":
                        req_update = True
                elif np.isnan(float(val)) == False: 
                    cols = cols + str(col) + ", "
                    vals = vals + str(val) + ", "
                    if col != "filename":
                        req_update = True
            query = query + cols[:-2] + ") " + 'VALUES ' + vals[:-2] + ");"
            if req_update == True:
                queries = queries + [query]
                existing_ids = existing_ids + [row['filename']]
            
    return queries

# %%
def generateQueries(df, tableName, cursor):
    df_cols = df.columns
    tab_cols = getColumnNames(tableName, cursor)
    overlap = overlapColumns(df_cols, tab_cols)
    existing_ids = getExistingIds(tableName, cursor)
    cleaned = fixStrings(df)
    query_list = list_queries(cleaned, overlap, tableName, existing_ids)
    return query_list

# %% [markdown]
# ## Change Working Directory

# %%
import os
os.getcwd()
# Out:
# '/Users/jmachita03/Documents/GitHub/MSDS_SERA_capstone/RDS'

# %%
os.chdir("/Users/jmachita03/Desktop/Capstone/NLP")

# %%
data = pd.read_csv("normal_comparison_output_status.csv")

# %%
data.head()
# Out:
#       doctype  index               filename             study     model  \
# 0  transcript     21   2019_5_5C_Transcript  Behavior Study 2  behavior
# 1  transcript     18  2019_34_5C_Transcript  Behavior Study 2  behavior
# 2  transcript      1                 103-2C  Behavior Study 1  behavior
# 3  transcript      2                   6-2C  Behavior Study 1  behavior
# 4  transcript      9  2019_58_5C_Transcript  Behavior Study 2  behavior
#
#    skill    coach                                               text  \
# 0      1  person1  Yeah that can be tough. I totally agree. Usual...
# 1      1  person7  So, how are you feeling about that first ? Tha...
# 2      2      NaN  alright. Why don't you have a sit and we'll-- ...
# 3      2      NaN  So how do you feel about that? Really hard. Wh...
# 4      2  person3  alright. Nice job. Like so many questions for ...
#
#                          cleaned_vectorized_document  similarity_score
# 0  [0.6198429304314097, -0.16436602338468467, -0....          0.270622
# 1  [0.6361390756591526, -0.04385806229881961, -0....          0.300864
# 2  [0.4031709161284383, -0.08087668041599247, 0.2...          0.145846
# 3  [0.5472509215170646, -0.07767101051949, 0.2492...          0.244462
# 4  [0.5707874299747961, -0.07655687445423678, -0....          0.277304

# %%
queries = generateQueries(data, "Fidelity_Measures", cursor)

# %%
for query in queries:
    cursor.execute(query)

# %%
cursor.execute("SELECT * FROM Fidelity_Measures;")
result = cursor.fetchall()
colnames = [x[0] for x in cursor.description]
pd.DataFrame(result, columns=colnames)
# Out:
#        doctype                filename             study     model  skill  \
# 0   transcript                   10-2C  Behavior Study 1  behavior    2.0
# 1   transcript                  103-2C  Behavior Study 1  behavior    2.0
# 2   transcript  2019_101_5C_Transcript  Behavior Study 2  behavior    2.0
# 3   transcript  2019_106_5C_Transcript  Behavior Study 2  behavior    2.0
# 4   transcript  2019_119_5C_Transcript  Behavior Study 2  behavior    2.0
# 5   transcript   2019_20_5C_Transcript  Behavior Study 2  behavior    2.0
# 6   transcript   2019_22_5C_Transcript  Behavior Study 2  behavior    2.0
# 7   transcript   2019_34_5C_Transcript  Behavior Study 2  behavior    1.0
# 8   transcript   2019_38_5C_Transcript  Behavior Study 2  behavior    2.0
# 9   transcript   2019_42_5C_Transcript  Behavior Study 2  behavior    2.0
# 10  transcript    2019_5_5C_Transcript  Behavior Study 2  behavior    1.0
# 11  transcript   2019_58_5C_Transcript  Behavior Study 2  behavior    2.0
# 12  transcript   2019_61_5C_Transcript  Behavior Study 2  behavior    3.0
# 13  transcript   2019_66_5C_Transcript  Behavior Study 2  behavior    2.0
# 14  transcript   2019_74_5C_Transcript  Behavior Study 2  behavior    2.0
# 15  transcript   2019_75_5C_Transcript  Behavior Study 2  behavior    3.0
# 16  transcript   2019_81_5C_Transcript  Behavior Study 2  behavior    3.0
# 17  transcript   2019_87_5C_Transcript  Behavior Study 2  behavior    4.0
# 18  transcript   2019_97_5C_Transcript  Behavior Study 2  behavior    3.0
# 19  transcript                    6-2C  Behavior Study 1  behavior    2.0
# 20  transcript                    7-2C  Behavior Study 1  behavior    3.0
# 21  transcript                   72-2C  Behavior Study 1  behavior    4.0
# 22  transcript                   84-2C  Behavior Study 1  behavior    3.0
# 23  transcript                   89-2C  Behavior Study 1  behavior    3.0
# 24  transcript                   93-2C  Behavior Study 1  behavior    4.0
#
#       coach                                               text  \
# 0      None  Okay, so I think that wins. Dont like the simu...
# 1      None  alright. Why dont you have a sit and well-- we...
# 2   person5  Hello. Okay, so how do you think at first run ...
# 3   person3  So tell me how you feel about your first simul...
# 4      None  alright. So, how are you feeling about Okay. W...
# 5   person1  alright, so come on over. How do you feel that...
# 6   person5  Just go ahead and take a seat. Youre fine. You...
# 7   person7  So, how are you feeling about that first ? Tha...
# 8   person7  How are you feeling about the first simulation...
# 9   person3  Aside from terrible, before I tell you my feed...
# 10  person1  Yeah that can be tough. I totally agree. Usual...
# 11  person3  alright. Nice job. Like so many questions for ...
# 12  person3  Go ahead and tell me your thoughts about what ...
# 13  person4   alright, so how do you think that went? What ...
# 14  person4  alright. So firstly, how do you think it went?...
# 15  person4  alright. So, how do you feel about it?  So wha...
# 16  person7  So, how are you feeling about that first simul...
# 17  person3  What do you think you did well? Yeah. So, I no...
# 18  person3  I can tell that youre a little bit frustrated ...
# 19     None  So how do you feel about that? Really hard. Wh...
# 20     None  alright. So how do you think that went? What d...
# 21     None  So how do you feel about that? Yeah? Ethans a ...
# 22     None  So how do you feel about that first run? What ...
# 23     None  alright. So, first of all, how you think that ...
# 24     None  Come on I said   Um, so how are you feeling? H...
#
#                           cleaned_vectorized_document     similarity_score
# 0   [0.5194993709632443, 0.023576768930381554, 0.4...   0.2188967631854828
# 1   [0.4031709161284383, -0.08087668041599247, 0.2...  0.14584579980400875
# 2   [0.5741149744532488, -0.17514627745491707, -0....  0.19625426243213315
# 3   [0.5623479361279925, -0.18734489200306162, -0....    0.220109446777706
# 4   [0.5764204590246595, -0.03895625224437529, -0....   0.2520476945940342
# 5   [0.6059433028211592, -0.1602070625338875, 0.01...  0.25144857975928125
# 6   [0.604000330114129, -0.06524464897980672, -0.1...   0.2643317150237819
# 7   [0.6361390756591526, -0.04385806229881961, -0....  0.30086445752609503
# 8   [0.5822116460450054, -0.01135436117190061, -0....   0.2868702584122339
# 9   [0.5782576176773634, -0.1845167081384388, -0.1...   0.2432368806421149
# 10  [0.6198429304314097, -0.16436602338468467, -0....  0.27062211449407003
# 11  [0.5707874299747961, -0.07655687445423678, -0....  0.27730361744635723
# 12  [0.5857308257388976, -0.17879835165872462, -0....   0.2764156744033153
# 13  [0.5562146116395136, 0.041886888940056224, 0.2...    0.277442335294088
# 14  [0.6340172014976612, 0.03390615985090158, 0.15...   0.3368138178999184
# 15  [0.5522985299533579, 0.06468612744392137, 0.15...   0.3231548087311509
# 16  [0.628909629065172, -0.15462315762629905, -0.0...  0.25790529070422724
# 17  [0.5988738638989562, -0.28464286187245935, -0....   0.1863330619207272
# 18  [0.5622812189826345, -0.2423885536669524, -0.2...  0.22229518213505625
# 19  [0.5472509215170646, -0.07767101051949, 0.2492...  0.24446200622789965
# 20  [0.5985432945334412, 0.026909996996568868, 0.5...  0.26870264668672444
# 21  [0.5631591966288553, -0.14461435160156408, 0.2...   0.2354592531487008
# 22  [0.5415378955957224, -0.06078326062310378, 0.3...   0.2721958153445126
# 23  [0.5562795731182689, -0.05180811454241078, 0.4...   0.2314025337276677
# 24  [0.593572612614357, -0.16033280529275065, 0.26...  0.21136576511403327

# %% [markdown]
# ## Commit and Close

# %%
cnx.commit()
cnx.close()
