# %%
import pandas as pd
import numpy as np
from utils import cleanColumns,generateScoreVariables

# %%
data = pd.read_excel("../data/Summer 2018 Behavioral Redirections Baseline.xlsx",sheet_name='Summer 2018 Behavioral Redirect',skiprows=[1,2])

# %%
data = data.iloc[:,2:]
data.columns = cleanColumns(data.columns)

# %%
generateScoreVariables(data,data.columns[17:23].values,{"No":0, "Yes":1,".":np.nan})

# %%
data[['b1oc','b2oc','b3oc','b4oc','b5oc','b6oc']].sum(axis=1)
# Out:
# 0     6
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     5
# 10    6
# 11    6
# 12    6
# 13    6
# 14    6
# 15    6
# 16    6
# 17    6
# 18    6
# 19    6
# 20    6
# 21    6
# 22    6
# 23    6
# 24    6
# 25    6
# 26    6
# 27    6
# 28    6
# 29    6
# 30    6
# 31    5
# 32    6
# 33    6
# 34    6
# dtype: int64

# %%
data
# Out:
#         status       ipaddress  progress  duration (in seconds)  finished  \
# 0   IP Address    73.12.28.114       100                    962      True
# 1   IP Address    73.12.28.114       100                    141      True
# 2   IP Address    73.12.28.114       100                    302      True
# 3   IP Address    73.12.28.114       100                    250      True
# 4   IP Address    73.12.28.114       100                    134      True
# 5   IP Address    73.12.28.114       100                     85      True
# 6   IP Address    73.12.28.114       100                    183      True
# 7   IP Address    73.12.28.114       100                     78      True
# 8   IP Address    73.12.28.114       100                    108      True
# 9   IP Address    73.12.28.114       100                    254      True
# 10  IP Address    73.12.28.114       100                    283      True
# 11  IP Address    73.12.28.114       100                     68      True
# ...
