# %%
#replicating 2d stata file
import pandas as pd
import numpy as np
from utils import *

# %%
#define a function to convert columns name to intutitive column names
def convert_cols(df):
    #rename the columns in all 2(survey) stata do file to intuitive column names
    df=df.rename({
                        'q1':'email',
                        'q4_1':'sim_fbsk',
                        'q5':'sim_txt_fbsk',
                        'q6_1':'sim_cmsk',
                        'q7':'sim_txt_cmsk',
                        'q8':'sim_txt_eth_behavior',
                        'q9':'sim_txt_eth_contribute',
                        'q10_1':'beh_fidgeting',
                        'q10_2':'beh_humming',
                        'q10_3':'beh_excitable',
                        'q10_4':'beh_inattentive',
                        'q10_5':'beh_short_attention',
                        'q10_6':'beh_quarrelsome',
                        'q10_7':'beh_acts_smart',
                        'q10_8':'beh_unpredictable',
                        'q10_9':'beh_defiant',
                        'q10_10':'beh_uncooperative',
                        'q10_11':'beh_easily_frustrated',
                        'q10_12':'beh_disturbs_others',
                        'q10_13':'beh_restless',
                        'q10_14':'beh_mood_changes',
                        'q11_1':'app_coach_stu',
                        'q12_1':'app_adjust_expect',
                        'q13_1':'app_guidance_couns',
                        'q14_1':'app_rec_sped',
                        'q15_1':'app_discp_refer',
                        'q16_1':'app_confer_stu',
                        'q17_1':'app_confer_parent',
                        'q18_1':'app_behavior_plan',
                        'q19_1':'app_challenge_work',
                        'q20_1':'app_spend_time',
                        'q21_1':'app_space_regroup',
                        'q22_1':'app_beh_manage_coach',
                        'q23_1':'app_beh_manage_teach',
                        'q24':'sim_txt_supports',
                        'q25_1':'sim_nervous',
                        'q25_2':'sim_beneficial',
                        'q25_3':'sim_worried_perform',
                        'q25_4':'sim_useful_tool',
                        'q25_5':'sim_relevant_studies',
                        'q25_6':'sim_relevant_prof',
                        'q25_7':'sim_like_use_again',
                        'q25_8':'sim_recommend',
                        'q25_9':'sim_sufficient_prep',
                        'q25_10':'sim_enough_time',
                        'q26':'sim_txt_beneficial',
                        'q27':'sim_txt_improve_exp',
                        'q28':'sim_txt_concerns' 
                       },axis=1)
    return df

# %%
data = pd.read_csv("../data/Post-Simulator Student Survey Round 2- Spring 2019_July 24, 2019_15.24.csv",skiprows=[1,2])
data.head()
# Out:
#              StartDate              EndDate          Status        IPAddress  \
# 0  2019-04-09 13:23:01  2019-04-09 13:27:01  Survey Preview              NaN
# 1  2019-04-12 16:07:32  2019-04-12 16:47:08      IP Address  199.111.228.146
# 2  2019-04-12 16:47:25  2019-04-12 16:54:30      IP Address  199.111.228.146
# 3  2019-04-15 14:24:52  2019-04-15 14:51:30      IP Address  199.111.228.146
# 4  2019-04-15 14:52:04  2019-04-15 15:30:21      IP Address  199.111.228.146
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                    239      True  2019-04-09 13:27:01
# 1       100                   2375      True  2019-04-12 16:47:08
# 2       100                    425      True  2019-04-12 16:54:30
# 3       100                   1598      True  2019-04-15 14:51:30
# 4       100                   2297      True  2019-04-15 15:30:22
#
#           ResponseId  RecipientLastName  ...              Q25_9  \
# 0  R_1gwGnCDFBaVjcBF                NaN  ...  Strongly disagree
# 1  R_22Y3oGDhHHE1KfS                NaN  ...     Somewhat agree
# 2  R_1n3Mf5A1yQDFg5S                NaN  ...     Strongly agree
# 3  R_pPNzi5xgQe58wvf                NaN  ...          Undecided
# 4  R_25ydjEgaFStnwSM                NaN  ...          Undecided
#
#               Q25_10                                                Q26  \
# 0  Somewhat disagree                                                  a
# 1     Somewhat agree  This time, it was nice to feel confident in my...
# 2     Strongly agree                                                NaN
# 3          Undecided  It has made me more aware of how I respond whe...
# 4          Undecided  The chance to have uncomfortable teaching expe...
#
#                                                  Q27  \
# 0                                                  a
# 1  I appreciate having more control over what I w...
# 2                       Timing of simulator sessions
# 3                                                NaN
# 4  The simulator experience always felt very diff...
#
#                              Q28 Q34 Q35_1 Q36_1  Q37  Q38
# 0                              a  No   NaN   NaN  NaN  NaN
# 1  I personally am not concerned  No   NaN   NaN  NaN  NaN
# 2                            NaN  No   NaN   NaN  NaN  NaN
# 3                            NaN  No   NaN   NaN  NaN  NaN
# 4                           None  No   NaN   NaN  NaN  NaN
#
# [5 rows x 71 columns]

# %%
data.columns = cleanColumns(data.columns)
#drop unnecessary observation
data = data[data['q1'].notna()]
#drop unnecessary variables
unused_columns=['enddate', 'status', 'ipaddress', 'progress',
       'duration (in seconds)', 'finished', 'recordeddate', 'responseid',
       'recipientlastname', 'recipientfirstname', 'recipientemail',
       'externalreference', 'locationlatitude', 'locationlongitude',
       'distributionchannel', 'userlanguage']
data=data.drop(columns=unused_columns)
#rename the columns to intuitive names
data=convert_cols(data)
data.columns
format_email(data)
# Out:
# C:\Users\15182\Documents\MSDS\MSDS_SERA_capstone\cleaning\utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email_fix['email']=email_fix['email'].apply(lambda x:fix_email_add(x))

# %%
#drop the duplicate
data=drop_duplicate(data)

# %%
#drop startdate
data=data.drop(columns=['startdate'])

# %%
#map for converting numeric to category and category to numeric
reverse_beh = {1:"Not at all", 2: "Just a little", 3: "Pretty much" ,4: "Very much"}
reverse_sim = {5: "Strongly agree", 4:"Somewhat agree", 3: "Undecided", 2: "Somewhat disagree", 1: "Strongly disagree"}
beh_map={"Not at all":1,  "Just a little":2,  "Pretty much":3 , "Very much":4}
sim_map={"Strongly agree":5, "Somewhat agree":4, "Undecided":3, "Somewhat disagree":2, "Strongly disagree":1}
app_map = {1:10, 2:9, 3:8,4:7,5:6,6:5,7:4,8:3,9:2,10:1}

# %%
#convert columns to right data type
convert_columns(data,beh_map,sim_map)
convert_numeric(data)
#generate Iowa Score Scaling
generate_Iowa_Score_Scale(data)

# %%
#reverse the approcch scale
Reverse_Approach_Scale(data,app_map)
#generate approach scale
Generate_App_Scale(data)
#convert the numeric columns back to categorical data
convert_columns(data,reverse_beh,reverse_sim)

# %%
data
# Out:
#                   email  sim_fbsk  \
# 1   hnj2gq@virginia.edu       6.0
# 2   wmn6kc@virginia.edu       9.0
# 3   zrh3aq@virginia.edu       6.0
# 4   bab7rr@virginia.edu       8.0
# 5   wwb4ka@virginia.edu       8.0
# ..                  ...       ...
# 75   hlh9j@virginia.edu       7.0
# 76  ekh2wb@virginia.edu       8.0
# 77  oce7ph@virginia.edu       7.0
# 78   rb2rf@virginia.edu       5.0
# 79  esw4au@virginia.edu       7.0
#
#                                                affect  q39  sim_cmsk  \
# 1   My feedback was more akin to positive reinforc...  NaN       7.0
# 2   I asked students to provide text evidence and ...  NaN       8.0
# 3   I felt a little scatter-brained today and I th...  NaN       9.0
# 4   Students seemed  to identify good answers to t...  NaN       7.0
# 5   '- We started to delve into the reasons why Li...  NaN       8.0
# ..                                                ...  ...       ...
# 75  Had students refer back to the text to find an...  NaN       6.0
# 76  '-did a good job of connecting individual stud...  NaN       7.0
# 77  I directed students to find textual evidence.\...  NaN       8.0
# 78  I gave them feedback on what I liked that they...  NaN       4.0
# 79  the students did a really good job at pulling ...  NaN       7.0
#
#                                                 score  \
# 1   My classroom helped us continue forward with t...
# 2   I heard from multiple students about their ide...
# 3   Everyone was able to participate in the discus...
# 4   Students identified several (I think 3) norms;...
# 5   '- Ethan was fairly on point, and not a major ...
# ..                                                ...
# 75  Students thought of three rules and had reason...
# 76  '-modeling a classroom norm example before giv...
# 77  I set expectations of taking turns to talk so ...
# 78  I think the expectations we were setting were ...
# 79  Everyone spoke, but the students who contribut...
#
#                                             rationale  \
# 1   Ethan exhibited disruptive behavior such as hu...
# 2   Some distraction, inattentiveness. Spoke out o...
# 3   '-Fidgeting\n-Attention seeking\n-Difficulty c...
# 4                  Off-task and distracting to others
# 5   Not to bad.  He was fairly on target throughou...
# ..                                                ...
# 75                          Distractable, high energy
# 76               '-distracted\n-sidetracked\n-fidgety
# 77                           distracted \ndisengaged
# 78  He wasn't really misbehaving, he was just bore...
# 79    A little distracted, but willing to participate
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 1   Ethan may be hyperactive on some level and  si...      Very much
# 2   Possibly LD. I would need access to IEP, 504, ...  Just a little
# 3          He may have an attention deficit disorder.      Very much
# 4   Many things might contribute to his behavior, ...    Pretty much
# 5                                            Boredom.  Just a little
# ..                                                ...            ...
# 75  He is a high energy student that would benefit...      Very much
# 76  '-not being comfortable in this setting/with t...  Just a little
# 77  He could be distracted by other students behav...    Pretty much
# 78  I would like to know how this student copes wi...  Just a little
# 79  He expressed his excitement to talk about what...    Pretty much
#
#       beh_humming  ... app_confer_stu_rc app_confer_parent_rc  \
# 1       Very much  ...               1.0                  1.0
# 2     Pretty much  ...               1.0                  4.0
# 3       Very much  ...               1.0                  1.0
# 4       Very much  ...               3.0                  3.0
# 5     Pretty much  ...               5.0                  8.0
# ..            ...  ...               ...                  ...
# 75      Very much  ...               4.0                  7.0
# 76      Very much  ...               1.0                  2.0
# 77      Very much  ...               1.0                  1.0
# 78    Pretty much  ...               1.0                  1.0
# 79  Just a little  ...               3.0                  6.0
#
#    app_behavior_plan_rc app_challenge_work_rc app_spend_time_rc  \
# 1                   1.0                   4.0               1.0
# 2                   7.0                  10.0               1.0
# 3                   2.0                   6.0               4.0
# 4                   4.0                   5.0               4.0
# 5                   6.0                   4.0               5.0
# ..                  ...                   ...               ...
# 75                  3.0                   9.0               8.0
# 76                  1.0                   6.0               3.0
# 77                  1.0                   5.0               1.0
# 78                  1.0                   4.0               3.0
# 79                  2.0                   6.0               5.0
#
#    app_space_regroup_rc app_beh_manage_coach_rc app_beh_manage_teach_rc  \
# 1                   3.0                     1.0                     1.0
# 2                   6.0                     5.0                     3.0
# 3                   7.0                     4.0                     3.0
# 4                   5.0                     4.0                     3.0
# 5                   7.0                     6.0                     4.0
# ..                  ...                     ...                     ...
# 75                  5.0                     7.0                     9.0
# 76                  1.0                     4.0                     3.0
# 77                  5.0                     1.0                     3.0
# 78                  3.0                     4.0                     9.0
# 79                  3.0                     7.0                     2.0
#
#    manage_app_negative manage_app_positive
# 1                  5.2               9.375
# 2                  2.6               6.375
# 3                  3.6               7.500
# 4                  7.4               7.125
# 5                  1.8               5.375
# ..                 ...                 ...
# 75                 1.8               4.500
# 76                 5.2               8.375
# 77                 2.6               8.750
# 78                 3.4               7.750
# 79                 3.2               6.750
#
# [78 rows x 72 columns]
