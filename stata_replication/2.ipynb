# %%
import pandas as pd
import numpy as np
from utils import *

# %%
#define a function to convert columns name to intutitive column names
def convert_cols(df):
    #rename the columns in all 2(survey) stata do file to intuitive column names
    df=df.rename({
                        'q1':'email',
                        'q4_1':'sim_fbsk',
                        'q5':'sim_txt_fbsk',
                        'q6_1':'sim_cmsk',
                        'q7':'sim_txt_cmsk',
                        'q8':'sim_txt_eth_behavior',
                        'q9':'sim_txt_eth_contribute',
                        'q10_1':'beh_fidgeting',
                        'q10_2':'beh_humming',
                        'q10_3':'beh_excitable',
                        'q10_4':'beh_inattentive',
                        'q10_5':'beh_short_attention',
                        'q10_6':'beh_quarrelsome',
                        'q10_7':'beh_acts_smart',
                        'q10_8':'beh_unpredictable',
                        'q10_9':'beh_defiant',
                        'q10_10':'beh_uncooperative',
                        'q10_11':'beh_easily_frustrated',
                        'q10_12':'beh_disturbs_others',
                        'q10_13':'beh_restless',
                        'q10_14':'beh_mood_changes',
                        'q11_1':'app_coach_stu',
                        'q12_1':'app_adjust_expect',
                        'q13_1':'app_guidance_couns',
                        'q14_1':'app_rec_sped',
                        'q15_1':'app_discp_refer',
                        'q16_1':'app_confer_stu',
                        'q17_1':'app_confer_parent',
                        'q18_1':'app_behavior_plan',
                        'q19_1':'app_challenge_work',
                        'q20_1':'app_spend_time',
                        'q21_1':'app_space_regroup',
                        'q22_1':'app_beh_manage_coach',
                        'q23_1':'app_beh_manage_teach',
                        'q24':'sim_txt_supports',
                        'q25_1':'sim_nervous',
                        'q25_2':'sim_beneficial',
                        'q25_3':'sim_worried_perform',
                        'q25_4':'sim_useful_tool',
                        'q25_5':'sim_relevant_studies',
                        'q25_6':'sim_relevant_prof',
                        'q25_7':'sim_like_use_again',
                        'q25_8':'sim_recommend',
                        'q25_9':'sim_sufficient_prep',
                        'q25_10':'sim_enough_time',
                        'q26':'sim_txt_beneficial',
                        'q27':'sim_txt_improve_exp',
                        'q28':'sim_txt_concerns' 
                       },axis=1)
    return df

# %%
def clean_survey_data(data):
    data.columns = cleanColumns(data.columns)
    #drop unnecessary observation
    data = data[data['q1'].notna()]
    #drop unnecessary variables
    unused_columns=['enddate', 'status', 'ipaddress', 'progress',
       'duration (in seconds)', 'finished', 'recordeddate', 'responseid',
       'recipientlastname', 'recipientfirstname', 'recipientemail',
       'externalreference', 'locationlatitude', 'locationlongitude',
       'distributionchannel', 'userlanguage']
    data=data.drop(columns=unused_columns)
    #rename the columns to intuitive names
    data=convert_cols(data)
    format_email(data)
    data=drop_duplicate(data)
    data=data.drop(columns=['startdate'])
    reverse_beh = {1:"Not at all", 2: "Just a little", 3: "Pretty much" ,4: "Very much"}
    reverse_sim = {5: "Strongly agree", 4:"Somewhat agree", 3: "Undecided", 2: "Somewhat disagree", 1: "Strongly disagree"}
    beh_map={"Not at all":1,  "Just a little":2,  "Pretty much":3 , "Very much":4}
    sim_map={"Strongly agree":5, "Somewhat agree":4, "Undecided":3, "Somewhat disagree":2, "Strongly disagree":1}
    app_map = {1:10, 2:9, 3:8,4:7,5:6,6:5,7:4,8:3,9:2,10:1}
    #convert columns to right data type
    convert_columns(data,beh_map,sim_map)
    convert_numeric(data)
    #generate Iowa Score Scaling
    generate_Iowa_Score_Scale(data)
    #reverse the approcch scale
    Reverse_Approach_Scale(data,app_map)
    #generate approach scale
    Generate_App_Scale(data)
    #convert the numeric columns back to categorical data
    convert_columns(data,reverse_beh,reverse_sim)
    
    return data

# %%
def clean_redo_data(data):
    data.columns = cleanColumns(data.columns)
    #drop unnecessary observation
    data = data[data['q1'].notna()]
    #drop unnecessary variables
    unused_columns=['enddate', 'status', 'ipaddress', 'progress',
       'duration (in seconds)', 'finished', 'recordeddate', 'responseid',
       'recipientlastname', 'recipientfirstname', 'recipientemail',
       'externalreference', 'locationlatitude', 'locationlongitude',
       'distributionchannel', 'userlanguage']
    data=data.drop(columns=unused_columns)
    #rename the columns to intuitive names
    data=convert_cols(data)
    format_email(data)
    data=drop_duplicate(data)
    data=data.drop(columns=['startdate'])
    reverse_beh = {1:"Not at all", 2: "Just a little", 3: "Pretty much" ,4: "Very much"}
    reverse_sim = {5: "Strongly agree", 4:"Somewhat agree", 3: "Undecided", 2: "Somewhat disagree", 1: "Strongly disagree"}
    beh_map={"Not at all":1,  "Just a little":2,  "Pretty much":3 , "Very much":4}
    sim_map={"Strongly agree":5, "Somewhat agree":4, "Undecided":3, "Somewhat disagree":2, "Strongly disagree":1}
    app_map = {1:10, 2:9, 3:8,4:7,5:6,6:5,7:4,8:3,9:2,10:1}
    #generate Iowa Score Scaling
    generate_Iowa_Score_Scale(data)
    #reverse the approcch scale
    Reverse_Approach_Scale(data,app_map)
    #generate approach scale
    Generate_App_Scale(data)
    #convert the numeric columns back to categorical data
    data.loc[:,'beh_fidgeting':'beh_mood_changes']=data.loc[:,'beh_fidgeting':'beh_mood_changes'].astype("int")
    data.loc[:,'beh_fidgeting':'beh_mood_changes']=data.loc[:,'beh_fidgeting':'beh_mood_changes'].replace(reverse_beh)
    
    
    return data

# %%
data_2a = pd.read_csv("../data/Post-Simulator Baseline Student Survey- Summer 2018_January 22, 2020_16.58.csv",skiprows=[1,2])
data_2a.head()
# Out:
#              StartDate              EndDate          Status        IPAddress  \
# 0  2018-05-30 12:23:22  2018-05-30 12:24:48  Survey Preview              NaN
# 1  2018-05-30 13:30:45  2018-05-30 13:32:13  Survey Preview              NaN
# 2  2018-06-08 07:18:04  2018-06-08 07:36:22      IP Address  199.111.228.147
# 3  2018-06-08 07:57:16  2018-06-08 08:09:18      IP Address  199.111.228.147
# 4  2018-06-08 08:19:08  2018-06-08 08:42:41      IP Address  199.111.228.147
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                     86      True  2018-05-30 12:24:49
# 1       100                     87      True  2018-05-30 13:32:13
# 2       100                   1097      True  2018-06-08 07:36:22
# 3       100                    722      True  2018-06-08 08:09:18
# 4       100                   1412      True  2018-06-08 08:42:41
#
#           ResponseId  RecipientLastName  ...           Q25_4           Q25_5  \
# 0  R_1opCvzbgQYDLHKN                NaN  ...  Somewhat agree  Strongly agree
# 1  R_1JEm2v4BI4ajTNP                NaN  ...             NaN             NaN
# 2  R_ZKuGL3K4Mp1Gked                NaN  ...  Strongly agree  Strongly agree
# 3  R_SCWEWpvi6QkN4U9                NaN  ...  Strongly agree  Somewhat agree
# 4  R_1kMOho2B2VK5Hkr                NaN  ...  Strongly agree  Strongly agree
#
#             Q25_6           Q25_7              Q25_8              Q25_9  \
# 0  Somewhat agree       Undecided  Somewhat disagree  Strongly disagree
# 1             NaN             NaN                NaN                NaN
# 2  Strongly agree  Strongly agree     Strongly agree     Somewhat agree
# 3  Somewhat agree  Strongly agree     Strongly agree     Somewhat agree
# 4  Strongly agree  Strongly agree     Strongly agree     Somewhat agree
#
#               Q25_10                                                Q26  \
# 0  Somewhat disagree                                                NaN
# 1                NaN                                                NaN
# 2     Strongly agree  It felt like an actual classroom\n\nThe differ...
# 3     Somewhat agree  Being able to try out certain ways of speaking...
# 4     Somewhat agree  Thinking about wait time.  I talked over the s...
#
#                                                  Q27                Q28
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  It was sort of hard to understand what they we...               none
# 3                Increased volume and vocal clarity.              None.
# 4  I could use help developing ice breakers.  I a...  None at this time
#
# [5 rows x 65 columns]

# %%
#clean the data for 2a 
data_2a=clean_survey_data(data_2a)
# Out:
# C:\Users\15182\Documents\MSDS\MSDS_SERA_capstone\cleaning\utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email_fix['email']=email_fix['email'].apply(lambda x:fix_email_add(x))

# %%
#read the survey for redo
redo = pd.read_csv("../data/Post-Simulator Baseline Student Survey (only for Redos)- Summer 2018 - Copy_January 23, 2020_07.22.csv",skiprows=[1,2])
redo.head()
# Out:
#              StartDate              EndDate  Status        IPAddress  \
# 0  2018-06-20 07:34:36  2018-06-20 07:36:32       1              NaN
# 1  2018-06-20 14:16:39  2018-06-20 14:34:03       0  199.111.228.151
# 2  2018-06-20 14:36:56  2018-06-20 14:40:54       0  199.111.228.151
# 3  2018-06-20 14:44:08  2018-06-20 14:52:47       0  199.111.228.151
# 4  2018-06-20 15:03:08  2018-06-20 15:09:22       0  199.111.228.151
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                    116         1  2018-06-20 07:36:33
# 1       100                   1044         1  2018-06-20 14:34:04
# 2       100                    238         1  2018-06-20 14:40:55
# 3       100                    519         1  2018-06-20 14:52:47
# 4       100                    374         1  2018-06-20 15:09:23
#
#           ResponseId  RecipientLastName  ...  Q15_1  Q16_1  Q17_1  Q18_1  \
# 0  R_d6V6xXmfUqeOLW9                NaN  ...    6.0    7.0    6.0    6.0
# 1  R_PNyNPjWT61T3ZG9                NaN  ...    3.0   10.0    7.0    8.0
# 2  R_2ymCxxAGFvqhaAJ                NaN  ...    1.0    5.0    4.0    6.0
# 3  R_1jUhlkPaIzNIy00                NaN  ...    2.0   10.0   10.0   10.0
# 4  R_1ezqC68mwIsFsx6                NaN  ...    1.0    5.0    5.0    8.0
#
#    Q19_1 Q20_1 Q21_1 Q22_1 Q23_1  \
# 0    7.0   7.0   7.0   7.0   7.0
# 1    6.0  10.0   8.0   7.0  10.0
# 2    6.0   8.0   9.0   7.0   7.0
# 3    7.0  10.0   4.0  10.0  10.0
# 4    7.0   6.0   9.0   6.0  10.0
#
#                                                  Q24
# 0                                                  A
# 1  Breaking off into groups may be a good way to ...
# 2  might need help with how to deal with defiant ...
# 3  '- attention getter - in some classrooms i hav...
# 4  '-background knowledge on Ethan (techniques th...
#
# [5 rows x 48 columns]

# %%
#cleanning the redo data
redo=clean_redo_data(redo)

# %%
#mannual correct email id for redo data
i = redo[((redo.email == 'kr2tvd@virginia.edu'))].index
redo.at[i,'email']="krv2td@virginia.edu"

# %%
#merge the dataset using redo to update the datas
redo = redo.set_index('email')
data_2a = data_2a.set_index('email')
data_2a.update(redo)
data_2a=data_2a.sort_values(by=['email'])
data_2a.reset_index(inplace=True)
data_2a
# Out:
#                   email  sim_fbsk  \
# 0   ajm8gx@virginia.edu      10.0
# 1   alh8pk@virginia.edu       5.0
# 2    alp7q@virginia.edu       5.0
# 3   art2vr@virginia.edu       6.0
# 4   bab7rr@virginia.edu       8.0
# 5   bbp5rr@virginia.edu       6.0
# 6    blt9q@virginia.edu       8.0
# 7    cnr5a@virginia.edu       6.0
# 8   ecu2ug@virginia.edu       7.0
# 9   ema4ex@virginia.edu       7.0
# 10  enl2ta@virginia.edu       8.0
# 11   es8fa@virginia.edu       4.0
# 12   gct2y@virginia.edu       6.0
# 13  hnj2gq@virginia.edu       9.0
# 14   jl6kc@virginia.edu       7.0
# 15  jlg2ga@virginia.edu       9.0
# 16  jmd4af@virginia.edu       5.0
# 17  jml5yb@virginia.edu       8.0
# 18  jms3ea@virginia.edu       7.0
# 19   js6aa@virginia.edu       5.0
# 20  kby6hf@virginia.edu       2.0
# 21   krf8j@virginia.edu       7.0
# 22  krv2td@virginia.edu       3.0
# 23   lcs6t@virginia.edu       4.0
# 24  mgp5fq@virginia.edu       5.0
# 25   nf2dm@virginia.edu       7.0
# 26  orh7wn@virginia.edu       6.0
# 27   sdr9x@virginia.edu       5.0
# 28  wmn6kc@virginia.edu       7.0
# 29  wwb4ka@virginia.edu       6.0
# 30   yk5kb@virginia.edu       6.0
# 31  zrh3aq@virginia.edu       6.0
#
#                                                affect  sim_cmsk  \
# 0   '-I think that delving into the background of ...      10.0
# 1   They seemed to have a good grasp on what made ...       NaN
# 2   '- I thought I did okay with going from questi...       2.0
# 3   I honestly was more concerned with making sure...       7.0
# 4   The students were on-task and seemed intereste...       4.0
# 5   I think I definitely helped them talk and thin...       6.0
# 6   I provided follow up questions.\r\n\r\nI also ...       3.0
# 7   When I asked about the way Lisa felt when aske...       7.0
# 8   '-I attempted to use guiding statements to exp...       2.0
# 9   I used positive feedback to reinforce their ex...       7.0
# 10  '- Asked why they thought what they thought\n-...       2.0
# 11  '-asking questions about why a student felt a ...       NaN
# 12  A few of the students seemed a bit confused ab...       5.0
# 13  They seemed to grasp the overall idea of suspe...      10.0
# 14  I was able to redirect answers and get student...       3.0
# 15  '-talked about suspense and our own understand...      10.0
# 16  >Used literary definitions to help students un...       4.0
# 17  '-I asked students to turn and talk to their c...       4.0
# 18  I think my feedback helped the students in the...       7.0
# 19  '- we are unsure of identity, reasons why it c...       2.0
# 20  '- I started with question 3 because I believe...       5.0
# 21  I was able to elicit descriptions of character...       4.0
# 22  1. I redirected their answers back to the text...       4.0
# 23  '-Our discussion helped them come up with theo...       2.0
# 24  I wasn't very comfortable with the simulation ...       5.0
# 25  Initially everyone kept their answers to the q...       NaN
# 26  I think that I added some extra questions that...       4.0
# 27  '--I focused more on giving them a way to rela...       7.0
# 28  I think my feedback allowed everyone to voice ...      10.0
# 29  Ethan didn't initially think Lisa was nervous,...       5.0
# 30  '-I asked students to explain their rationale ...       8.0
# 31  '-I asked students to give their responses to ...       NaN
#
#                                                 score  \
# 0   '-In disciplining Ethan I was able to make sur...
# 1   I couldn't get to the discussion about class n...
# 2   I had a brief moment of success when Savannah ...
# 3   I think I did a good job on this. I asked the ...
# 4   The class provided one class expectation (to b...
# 5   I thought I did a good job of managing to get ...
# 6   I was having trouble getting through to the st...
# 7   I used the way some of the students were actin...
# 8   '- I wasn't able to get the group on task/when...
# 9   I think I handled Ethan's distracting behavior...
# 10  '- I couldn't successfully redirect a disrupti...
# 11  '-I had a hard time reigning in the class due ...
# 12  The students provided great ideas, but even th...
# 13  I went around in a circle so that everyone had...
# 14  I had next to no idea how to get students to a...
# 15  '-we all agreed on the norms\n-the students we...
# 16  > Had a difficult time encouraging Ethan to pa...
# 17  '-I felt frustrated with some students for the...
# 18  I think I did a good job helping the kids agre...
# 19  '- I had a really hard time quieting them\n- d...
# 20  '- Responses on classroom norms were more help...
# 21  While I was able to produce rules, I wasn't ab...
# 22  1. I allowed the students to discuss with each...
# 23  '-Had a hard time getting Ethan to focus\n-abl...
# 24  I was not prepared for students to misbehave s...
# 25  Absolutely no question that I couldn't even be...
# 26  I gave myself a 4 because I tried to stop some...
# 27  '--I really liked giving them ownership of und...
# 28  I asked the students as a whole for ideas, and...
# 29  Managed the class and kept the class in "order...
# 30  '-Although there was an awkward silence, conve...
# 31  '-I couldn't get the students to focus long en...
#
#                                             rationale  \
# 0   Ethan was off-task often.\nHe interrupted othe...
# 1   Ethan was very distracted, full of energy, and...
# 2   He was disruptive but occasionally responsive ...
# 3   Super distracting. Every time I thought he was...
# 4   In this situation, Ethan was very off-task and...
# 5   Ethan wanted to do his own thing, and was in h...
# 6   He was very off task and disrespectful to both...
# 7   Ethan was very disruptive and distracting. He ...
# 8   Ethan was disengaged and focused on his own ac...
# 9   He was loud, distracting, and wanted to talk t...
# 10         '- Stubborn\n- Inappropriate\n- Disruptive
# 11  '-He was distracted.\n-He did not listen to th...
# 12                          disruptive, disrespectful
# 13  '-he had a lot of energy and was expelling it ...
# 14  Ethan's behavior was very distracted but predi...
# 15  '-disruptive\n-short attention span\n-smart al...
# 16  > Distracted\n> Off task \n> Disruptive to oth...
# 17  '-distracted\n-flippant/defiant of authority\n...
# 18                '-Distracting -Uncooperative -Rude
# 19  '- loud\n- potentially has a learning disabili...
# 20  '- distracted\n- disruptive\n- persistent\n- u...
# 21      '-disruptive\n-annoying\n-attention-seeking\n
# 22                      '-Hyperactive\n-Distracted\n-
# 23  Ethan was having a hard time focus and him bei...
# 24  I think his individual behaviors is accurate, ...
# 25  Disruptive, inattentive, and perhaps intention...
# 26  Ethan was very distracted throughout the whole...
# 27  '-either wanting attention or can't control hi...
# 28                          Distracted and disruptive
# 29   Bored.\nWanted to be out of class.\nNot engaged.
# 30                                       distracted\n
# 31  Ethan is disruptive, he is having trouble enga...
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 0   He may have ADD or another IEP. He may have a ...      Very much
# 1   He may have a short attention span, possibly A...      Very much
# 2   I'd want to know if there was a reason why he ...      Very much
# 3   I think the guidance counselor and parent/guar...  Just a little
# 4   A real student may act this way in class becau...    Pretty much
# 5   Possible attention deficit disorders.\nEasily ...    Pretty much
# 6   I think Ethan has trouble concentrating and st...      Very much
# 7   The fact that Ethan could not remain still and...      Very much
# 8   Ethan probably has a negative relationship wit...      Very much
# 9   I think having Ethan on a bouncy ball chair wo...    Pretty much
# 10  '- Attention seeking\n- Boredom \n- I would li...  Just a little
# 11  Maybe he has been sitting for too long and is ...      Very much
# 12  bored, wants to be in a music class, maybe doe...    Pretty much
# 13  '-I would want to know about his home life and...      Very much
# 14  Based on this interaction in particular, I thi...      Very much
# 15  I think that he was really bored. He seems to ...      Very much
# 16  A disconnect with the material may encourage t...      Very much
# 17  He might have an attention disorder (ADD, ADHD...      Very much
# 18  He may have behavioral issues or attention iss...      Very much
# 19  I would probably try to pull this student asid...    Pretty much
# 20  '- lack of formal rules\n- have other teachers...      Very much
# 21  '-he is uninterested in the material\n-he has ...    Pretty much
# 22  '-behavior at home\n-past classroom experiences\n      Very much
# 23  There could be a lot of reasons- maybe he didn...      Very much
# 24  His home and family situation might be stresse...      Very much
# 25  I would think there might be some issue at hom...      Very much
# 26  I think that part of his behavior is based on ...      Very much
# 27  '--wanting attention or cant control himself (...  Just a little
# 28  Possible family issues or learning impairments...      Very much
# 29    Hyper-activity, needs an activity to engage. \n    Pretty much
# 30  possibly adhd or a learning disability, proble...      Very much
# 31  '-He might have ADHD\n-He might just be seekin...      Very much
#
#       beh_humming  beh_excitable  ... app_confer_stu_rc app_confer_parent_rc  \
# 0       Very much      Very much  ...               1.0                  1.0
# 1       Very much    Pretty much  ...               3.0                  2.0
# 2       Very much  Just a little  ...               1.0                  1.0
# 3       Very much    Pretty much  ...               1.0                  1.0
# 4       Very much      Very much  ...               3.0                  4.0
# 5   Just a little  Just a little  ...               2.0                  4.0
# 6       Very much  Just a little  ...               1.0                  3.0
# 7       Very much  Just a little  ...               3.0                  6.0
# 8       Very much    Pretty much  ...               2.0                  2.0
# 9     Pretty much  Just a little  ...               4.0                  4.0
# 10      Very much  Just a little  ...               2.0                  6.0
# 11      Very much    Pretty much  ...               3.0                  4.0
# 12      Very much  Just a little  ...               6.0                  7.0
# 13      Very much      Very much  ...               1.0                  4.0
# 14      Very much    Pretty much  ...               4.0                  3.0
# 15      Very much      Very much  ...               1.0                  4.0
# 16      Very much    Pretty much  ...               2.0                  2.0
# 17      Very much    Pretty much  ...               1.0                  1.0
# 18      Very much      Very much  ...               1.0                  2.0
# 19      Very much    Pretty much  ...               2.0                  6.0
# 20      Very much      Very much  ...               1.0                  1.0
# 21      Very much      Very much  ...               4.0                  4.0
# 22      Very much    Pretty much  ...               3.0                  4.0
# 23      Very much    Pretty much  ...               1.0                  4.0
# 24      Very much      Very much  ...               4.0                  7.0
# 25      Very much      Very much  ...               4.0                  1.0
# 26      Very much  Just a little  ...               3.0                  5.0
# 27      Very much    Pretty much  ...               6.0                  6.0
# 28      Very much  Just a little  ...               1.0                  1.0
# 29      Very much  Just a little  ...               5.0                  5.0
# 30      Very much      Very much  ...               1.0                  4.0
# 31      Very much    Pretty much  ...               5.0                  5.0
#
#    app_behavior_plan_rc app_challenge_work_rc app_spend_time_rc  \
# 0                   1.0                   5.0               1.0
# 1                   2.0                   4.0               4.0
# 2                   3.0                   7.0               3.0
# 3                   1.0                   6.0               1.0
# 4                   4.0                   7.0               6.0
# 5                   2.0                   6.0               5.0
# 6                   4.0                   8.0               2.0
# 7                   5.0                   7.0               2.0
# 8                   1.0                   7.0               2.0
# 9                   3.0                   3.0               4.0
# 10                  3.0                   6.0               7.0
# 11                  3.0                  10.0               3.0
# 12                  5.0                   5.0               3.0
# 13                  3.0                   5.0               1.0
# 14                  2.0                   5.0               2.0
# 15                  1.0                   2.0               1.0
# 16                  3.0                   6.0               3.0
# 17                  1.0                   3.0               1.0
# 18                  3.0                   4.0               2.0
# 19                  4.0                   8.0               6.0
# 20                  1.0                   4.0               1.0
# 21                  7.0                   9.0               3.0
# 22                  1.0                   6.0               2.0
# 23                  1.0                   5.0               1.0
# 24                  1.0                   3.0               1.0
# 25                  1.0                  10.0               1.0
# 26                  3.0                   9.0               3.0
# 27                  3.0                   4.0               5.0
# 28                  5.0                  10.0              10.0
# 29                  5.0                   9.0               5.0
# 30                  2.0                   9.0               1.0
# 31                  3.0                   6.0               5.0
#
#    app_space_regroup_rc app_beh_manage_coach_rc app_beh_manage_teach_rc  \
# 0                   2.0                     1.0                     1.0
# 1                   3.0                     2.0                     1.0
# 2                   6.0                     1.0                     1.0
# 3                   8.0                     1.0                     1.0
# 4                   7.0                     7.0                     4.0
# 5                   7.0                     6.0                     3.0
# 6                   7.0                     3.0                     1.0
# 7                   8.0                    10.0                     3.0
# 8                   3.0                     1.0                     1.0
# 9                   4.0                     6.0                     3.0
# 10                  6.0                     4.0                     1.0
# 11                  8.0                     7.0                     3.0
# 12                  2.0                     4.0                     4.0
# 13                  3.0                     4.0                     1.0
# 14                  3.0                     1.0                     1.0
# 15                  1.0                     4.0                     2.0
# 16                  4.0                     5.0                     2.0
# 17                  5.0                     1.0                     1.0
# 18                  5.0                     4.0                     1.0
# 19                  2.0                     3.0                     1.0
# 20                  7.0                     1.0                     1.0
# 21                  9.0                     5.0                     2.0
# 22                  4.0                     5.0                     3.0
# 23                  3.0                     3.0                     1.0
# 24                  4.0                     3.0                     1.0
# 25                  3.0                     3.0                     1.0
# 26                  6.0                     9.0                     4.0
# 27                  2.0                     5.0                     1.0
# 28                  5.0                     1.0                     1.0
# 29                  9.0                     7.0                     4.0
# 30                  3.0                     1.0                     1.0
# 31                  6.0                     8.0                     5.0
#
#    manage_app_negative manage_app_positive
# 0                  8.2               9.375
# 1                  5.0               8.375
# 2                  6.4               8.125
# 3                  5.2               8.500
# 4                  5.4               5.750
# 5                  3.0               6.625
# 6                  6.2               7.375
# 7                  3.8               5.500
# 8                  6.0               8.625
# 9                  5.0               7.125
# 10                 3.8               6.625
# 11                 3.2               5.875
# 12                 2.4               6.500
# 13                 4.0               8.250
# 14                 6.6               8.375
# 15                 6.4               9.000
# 16                 5.2               7.625
# 17                 7.4               9.250
# 18                 6.6               8.250
# 19                 4.8               7.000
# 20                 2.8               8.875
# 21                 3.6               5.625
# 22                 6.8               7.500
# 23                 4.4               8.625
# 24                 5.0               8.000
# 25                 4.0               8.000
# 26                 2.6               5.750
# 27                 3.6               7.000
# 28                 5.2               6.750
# 29                 2.0               4.875
# 30                 6.8               8.250
# 31                 2.4               5.625
#
# [32 rows x 66 columns]

# %%
data_2b = pd.read_csv("../data/Post-Simulator Baseline Student Survey- Fall 2018_July 24, 2019_15.43.csv",skiprows=[1,2])
data_2b.head()
# Out:
#              StartDate              EndDate      Status        IPAddress  \
# 0  2018-09-17 07:05:03  2018-09-17 07:36:27  IP Address  199.111.228.149
# 1  2018-09-17 07:37:53  2018-09-17 08:10:51  IP Address  199.111.228.149
# 2  2018-09-17 08:12:42  2018-09-17 08:35:28  IP Address  199.111.228.149
# 3  2018-09-17 08:35:42  2018-09-17 09:01:40  IP Address  199.111.228.149
# 4  2018-09-17 09:01:57  2018-09-17 09:17:03  IP Address  199.111.228.149
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                   1883      True  2018-09-17 07:36:28
# 1       100                   1978      True  2018-09-17 08:10:51
# 2       100                   1366      True  2018-09-17 08:35:29
# 3       100                   1557      True  2018-09-17 09:01:40
# 4       100                    905      True  2018-09-17 09:17:04
#
#           ResponseId  RecipientLastName  ...           Q25_4           Q25_5  \
# 0  R_22F9vTdxw2PCTFs                NaN  ...  Strongly agree  Strongly agree
# 1  R_24iVOclK34K8Awf                NaN  ...       Undecided  Strongly agree
# 2  R_3qlIj3VjGBL2EgZ                NaN  ...  Strongly agree  Strongly agree
# 3  R_1I9Q6ND18lHriSP                NaN  ...  Somewhat agree  Somewhat agree
# 4  R_Y3bp74qqJ6l5tWV                NaN  ...  Strongly agree  Strongly agree
#
#             Q25_6           Q25_7              Q25_8              Q25_9  \
# 0  Somewhat agree  Somewhat agree     Somewhat agree     Somewhat agree
# 1  Strongly agree  Somewhat agree     Somewhat agree  Strongly disagree
# 2  Strongly agree  Strongly agree     Strongly agree     Strongly agree
# 3  Strongly agree       Undecided  Somewhat disagree     Somewhat agree
# 4  Strongly agree  Somewhat agree     Somewhat agree     Somewhat agree
#
#            Q25_10                                                Q26  \
# 0  Strongly agree  It helped me to see how students may act in cl...
# 1  Somewhat agree  It brought weakness right into focus. I am rea...
# 2  Strongly agree  It exposed me to students who may have behavio...
# 3  Strongly agree  Seeing how I handle on the spot teaching, beha...
# 4       Undecided  It was actually pretty realistic. You didn't k...
#
#                                                  Q27  \
# 0  I thought the simulator was good and nothing n...
# 1  Feedback right then and there.\n\nPrior notice...
# 2                                                NaN
# 3  There were limitations such as only beginning ...
# 4  I wish that I knew better behavior management ...
#
#                                                  Q28
# 0  I have concerns about how I respond to childre...
# 1  How am I supposed to get feedback to improve? ...
# 2                                                NaN
# 3  I did not handle Ethan correctly and got easil...
# 4  I am a little worried that my teacher language...
#
# [5 rows x 65 columns]

# %%
#clean the data for 2b 
data_2b=clean_survey_data(data_2b)
data_2b
# Out:
# C:\Users\15182\Documents\MSDS\MSDS_SERA_capstone\cleaning\utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email_fix['email']=email_fix['email'].apply(lambda x:fix_email_add(x))
#                   email  sim_fbsk  \
# 0   cal4ab@virginia.edu       8.0
# 1    sem4u@virginia.edu       6.0
# 2    st5ah@virginia.edu       3.0
# 3   eyb7hn@virginia.edu       3.0
# 4   lal4rp@virginia.edu       5.0
# ..                  ...       ...
# 84  lgh5ed@virginia.edu       7.0
# 85   bh2vy@virginia.edu       2.0
# 88  klj9ww@virginia.edu       3.0
# 89  rhh2hd@virginia.edu       6.0
# 90  hcg4gu@virginia.edu       5.0
#
#                                                affect  sim_cmsk  \
# 0   ~ I asked the common question "Why" when anyon...       5.0
# 1   '- Students cited specific examples in the tex...       3.0
# 2   '-I asked for the students to go back in the t...       3.0
# 3   I put three because I did not come in that pre...       2.0
# 4   '- I told them to look back in the story to he...       3.0
# ..                                                ...       ...
# 84  '-prompting students to use the text as eviden...       3.0
# 85                                                NaN       6.0
# 88  I felt it was too structured towards getting a...       NaN
# 89  1) encouraging the students to support their s...       6.0
# 90  I tried to encourage further thought processes...       2.0
#
#                                                 score  \
# 0   ~ I was unable to get the students to focus on...
# 1   '- I should have used the behaviors happening ...
# 2   '-I asked students for classroom norms and exp...
# 3   I could not get Ethan to follow along with the...
# 4   '- I struggled to keep one student on task  \n...
# ..                                                ...
# 84  '-I could not get Ethan to settle down so once...
# 85         I was clear and direct with my instruction
# 88  Throughout both simulations there was never a ...
# 89  1) staying positive even when they were shouti...
# 90  I am not familiar with classroom management ye...
#
#                                             rationale  \
# 0   Ethan gave great answers for the discussion bu...
# 1   '-distracted; attention-seeking; full of energ...
# 2   '-distracting \n-making lots of noises \n-goin...
# 3   Interrupting by whistling, talking when the te...
# 4   Ethan was very distracted and unfocused. He ke...
# ..                                                ...
# 84           '-distant\n-unaware\n-bored\n-distracted
# 85  He needed frequent reminders, but listened whe...
# 88  He was very disruptive and loud specifically t...
# 89  1) distracting\n2) representative of his perso...
# 90              Disruptive, class clown type behavior
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 0   Ethan may be a student who just needs a little...  Just a little
# 1   I'd want to know if Ethan feels sensitive beca...      Very much
# 2   '-first day jitters \n-nervous\n\nIf he behave...    Pretty much
# 3   Being excited to be there and talk/participate...  Just a little
# 4   I think that maybe he was behind in school and...  Just a little
# ..                                                ...            ...
# 84  '-doing activities that involve movement\n-doi...    Pretty much
# 85  He may need clearer norms and expectations or ...  Just a little
# 88  I would want to know how he acts in previous g...  Just a little
# 89  It could be him trying to get attention from h...  Just a little
# 90  He seems to have a lot of energy and difficult...    Pretty much
#
#     beh_humming  beh_excitable  ... app_confer_stu_rc app_confer_parent_rc  \
# 0     Very much      Very much  ...               4.0                  6.0
# 1     Very much      Very much  ...               1.0                  4.0
# 2     Very much  Just a little  ...               1.0                  4.0
# 3     Very much    Pretty much  ...               1.0                  1.0
# 4     Very much  Just a little  ...               1.0                  2.0
# ..          ...            ...  ...               ...                  ...
# 84    Very much  Just a little  ...               1.0                  3.0
# 85  Pretty much     Not at all  ...               4.0                  6.0
# 88    Very much    Pretty much  ...               3.0                  2.0
# 89    Very much      Very much  ...               4.0                  3.0
# 90    Very much    Pretty much  ...               3.0                  3.0
#
#    app_behavior_plan_rc app_challenge_work_rc app_spend_time_rc  \
# 0                  10.0                  10.0               4.0
# 1                   1.0                   2.0               1.0
# 2                   3.0                   9.0               2.0
# 3                   1.0                   3.0               5.0
# 4                   3.0                   9.0               1.0
# ..                  ...                   ...               ...
# 84                  3.0                   1.0               1.0
# 85                  3.0                   5.0               2.0
# 88                  3.0                   4.0               2.0
# 89                  4.0                   3.0               3.0
# 90                  2.0                   7.0               3.0
#
#    app_space_regroup_rc app_beh_manage_coach_rc app_beh_manage_teach_rc  \
# 0                   5.0                    10.0                     7.0
# 1                   1.0                     1.0                     1.0
# 2                   4.0                     1.0                     1.0
# 3                   2.0                     1.0                     1.0
# 4                   6.0                     2.0                     1.0
# ..                  ...                     ...                     ...
# 84                  1.0                     1.0                     2.0
# 85                  3.0                     4.0                     5.0
# 88                  3.0                     7.0                     3.0
# 89                  3.0                     5.0                     3.0
# 90                  6.0                     5.0                     4.0
#
#    manage_app_negative manage_app_positive
# 0                  4.8               4.000
# 1                  3.0               9.500
# 2                  3.8               7.875
# 3                  5.8               9.125
# 4                  5.8               7.875
# ..                 ...                 ...
# 84                 5.0               9.375
# 85                 3.0               7.000
# 88                 4.4               7.625
# 89                 4.0               7.500
# 90                 4.6               6.875
#
# [85 rows x 66 columns]

# %%
data_2c = pd.read_csv("../data/Post-Simulator Student Survey (Round 1)- Spring 2019_July 24, 2019_15.25.csv",skiprows=[1,2])
data_2c.head()
# Out:
#              StartDate              EndDate          Status        IPAddress  \
# 0  2019-01-20 18:46:05  2019-01-20 18:49:38  Survey Preview              NaN
# 1  2019-01-22 11:12:23  2019-01-22 11:26:43      IP Address  199.111.228.151
# 2  2019-01-22 11:26:59  2019-01-22 11:48:54      IP Address  199.111.228.151
# 3  2019-01-22 11:49:07  2019-01-22 12:54:28      IP Address  199.111.228.151
# 4  2019-01-22 12:54:42  2019-01-22 13:13:40      IP Address  199.111.228.151
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                    213      True  2019-01-20 18:49:39
# 1       100                    859      True  2019-01-22 11:26:43
# 2       100                   1314      True  2019-01-22 11:48:54
# 3       100                   3920      True  2019-01-22 12:54:28
# 4       100                   1138      True  2019-01-22 13:13:41
#
#           ResponseId  RecipientLastName  ...              Q25_4  \
# 0  R_cPiHu7pdjpcOBTH                NaN  ...  Strongly disagree
# 1  R_1OqwMtwIuyFu8ug                NaN  ...     Strongly agree
# 2  R_RaH4s8MljpxDpx7                NaN  ...          Undecided
# 3  R_2ZNBPGvCjKHvS6e                NaN  ...          Undecided
# 4  R_3r0M3ZmQoPrWRvz                NaN  ...     Somewhat agree
#
#                Q25_5              Q25_6              Q25_7              Q25_8  \
# 0  Strongly disagree  Strongly disagree  Strongly disagree  Strongly disagree
# 1     Strongly agree     Strongly agree          Undecided     Somewhat agree
# 2     Somewhat agree     Somewhat agree  Strongly disagree          Undecided
# 3     Somewhat agree     Somewhat agree  Strongly disagree  Strongly disagree
# 4     Strongly agree     Strongly agree  Somewhat disagree     Somewhat agree
#
#                Q25_9             Q25_10  \
# 0  Strongly disagree  Strongly disagree
# 1          Undecided          Undecided
# 2          Undecided     Strongly agree
# 3     Somewhat agree     Strongly agree
# 4          Undecided     Somewhat agree
#
#                                                  Q26  \
# 0                                                  i
# 1  '-It gave me the chance to make mistakes becau...
# 2  It exposed me to potential disruptive behavior...
# 3                                       The coaching
# 4                learning behavior management skills
#
#                                                  Q27  \
# 0                                                  j
# 1      I feel more comfortable using the simulator.
# 2  Being prepared with strategies to try in the c...
# 3  Being able to use other tools such as proximit...
# 4         I thought this experience went really well
#
#                                                  Q28
# 0                                                  i
# 1     I still feel anxious when using the simulator.
# 2  I am concerned that I am not prepared to begin...
# 3  It takes a good amount of time and I feel our ...
# 4                                               none
#
# [5 rows x 63 columns]

# %%
#clean the data for 2c 
data_2c=clean_survey_data(data_2c)
# Out:
# C:\Users\15182\Documents\MSDS\MSDS_SERA_capstone\cleaning\utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email_fix['email']=email_fix['email'].apply(lambda x:fix_email_add(x))

# %%
#correct email id
i = data_2c[((data_2c.email == 'kr2a2fn@virginia.edu'))].index
data_2c.at[i,'email']="kra2fn@virginia.edu"

# %%
data_2c
# Out:
#                   email  sim_cmsk  \
# 1    st5ah@virginia.edu       7.0
# 2   eam4hf@virginia.edu       1.0
# 3    set9x@virginia.edu       7.0
# 4    rfg2m@virginia.edu       7.0
# 5   syc2rw@virginia.edu       2.0
# ..                  ...       ...
# 93  bac2dr@virginia.edu       8.0
# 94  rjk3mc@virginia.edu       7.0
# 95  slm3dk@virginia.edu       8.0
# 96  jlm3df@virginia.edu      10.0
# 97  cel9pk@virginia.edu       8.0
#
#                                                 score  \
# 1   '-I asked the students why we should have clas...
# 2   '-I was not able to facilitate a conversation ...
# 3   Generated ideas such as raising hand, respecti...
# 4   When a student would start to get off task or ...
# 5   I think I tried to ask students to contribute ...
# ..                                                ...
# 93  I called on students by names both times to en...
# 94  '- I was able to stop the distracting sounds a...
# 95  I asked for a lot of student input \nI did not...
# 96  '- I was allowed them to talk about themselves...
# 97  Students were asked to provide their own input...
#
#                                             rationale  \
# 1                    '-Distracting to others\n-Loud\n
# 2   '-Disruptive --> humming, texting, talking to ...
# 3   Distracting to others and teacher\nOff task\nN...
# 4   Ethan kept engaging in distracting behaviors, ...
# 5   '- distracted\n- desiring attention\n- not abl...
# ..                                                ...
# 93                                       '-distracted
# 94  '- lack of focus\n- I don't think he was tryin...
# 95  disruptive\ndistracting \na little concerning ...
# 96  He was just being a normal kid with a little t...
# 97  '- disruptive\n- distracted\n- but willing to ...
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 1   '-What we are doing in class is boring (not mo...  Just a little
# 2   I would want to know if Ethan had behavior lik...    Pretty much
# 3   Home life/expectations and norms at home\nPrev...    Pretty much
# 4   I would want to know about his home life outsi...    Pretty much
# 5   contributions: home life situation, friends, e...    Pretty much
# ..                                                ...            ...
# 93  '-if he's like this in other classes\n-if he g...  Just a little
# 94  '- I would like to know what his learning styl...  Just a little
# 95  I would want to know his breakfast diet (exces...      Very much
# 96  Based on this minimal interaction, I cannot re...      Very much
# 97  '- not having as much discipline at home or in...  Just a little
#
#       beh_humming  beh_excitable beh_inattentive beh_short_attention  ...  \
# 1     Pretty much    Pretty much       Very much         Pretty much  ...
# 2       Very much    Pretty much       Very much       Just a little  ...
# 3       Very much  Just a little       Very much         Pretty much  ...
# 4     Pretty much    Pretty much     Pretty much          Not at all  ...
# 5     Pretty much    Pretty much     Pretty much       Just a little  ...
# ..            ...            ...             ...                 ...  ...
# 93  Just a little    Pretty much     Pretty much          Not at all  ...
# 94    Pretty much  Just a little       Very much       Just a little  ...
# 95      Very much      Very much       Very much           Very much  ...
# 96      Very much      Very much     Pretty much          Not at all  ...
# 97  Just a little    Pretty much     Pretty much       Just a little  ...
#
#    app_confer_stu_rc app_confer_parent_rc app_behavior_plan_rc  \
# 1                1.0                  3.0                  3.0
# 2                5.0                  7.0                  4.0
# 3                1.0                  1.0                  1.0
# 4                2.0                  3.0                  4.0
# 5                1.0                  4.0                  3.0
# ..               ...                  ...                  ...
# 93               3.0                  5.0                  5.0
# 94               4.0                  7.0                  6.0
# 95               1.0                  1.0                  1.0
# 96               1.0                  4.0                  1.0
# 97               1.0                  4.0                  2.0
#
#    app_challenge_work_rc app_spend_time_rc app_space_regroup_rc  \
# 1                    9.0               4.0                  1.0
# 2                   10.0               5.0                  1.0
# 3                    6.0               1.0                  1.0
# 4                    7.0               4.0                  4.0
# 5                    7.0               1.0                  8.0
# ..                   ...               ...                  ...
# 93                   7.0               1.0                  4.0
# 94                   9.0               3.0                  5.0
# 95                   6.0               1.0                  1.0
# 96                   8.0               1.0                  9.0
# 97                   8.0               5.0                  4.0
#
#    app_beh_manage_coach_rc app_beh_manage_teach_rc manage_app_negative  \
# 1                      1.0                     1.0                 3.4
# 2                      1.0                     1.0                 1.6
# 3                      1.0                     1.0                 4.2
# 4                      4.0                     3.0                 6.4
# 5                      6.0                     1.0                 4.6
# ..                     ...                     ...                 ...
# 93                     6.0                     5.0                 2.8
# 94                     4.0                     3.0                 3.2
# 95                     1.0                     1.0                 5.8
# 96                    10.0                     1.0                 3.0
# 97                     7.0                     3.0                 3.6
#
#     manage_app_positive
# 1                 8.125
# 2                 6.750
# 3                 9.375
# 4                 7.125
# 5                 7.125
# ..                  ...
# 93                6.500
# 94                5.875
# 95                9.375
# 96                6.625
# 97                6.750
#
# [97 rows x 64 columns]

# %%
data_2d = pd.read_csv("../data/Post-Simulator Student Survey Round 2- Spring 2019_July 24, 2019_15.24.csv",skiprows=[1,2])
data_2d.head()
# Out:
#              StartDate              EndDate          Status        IPAddress  \
# 0  2019-04-09 13:23:01  2019-04-09 13:27:01  Survey Preview              NaN
# 1  2019-04-12 16:07:32  2019-04-12 16:47:08      IP Address  199.111.228.146
# 2  2019-04-12 16:47:25  2019-04-12 16:54:30      IP Address  199.111.228.146
# 3  2019-04-15 14:24:52  2019-04-15 14:51:30      IP Address  199.111.228.146
# 4  2019-04-15 14:52:04  2019-04-15 15:30:21      IP Address  199.111.228.146
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                    239      True  2019-04-09 13:27:01
# 1       100                   2375      True  2019-04-12 16:47:08
# 2       100                    425      True  2019-04-12 16:54:30
# 3       100                   1598      True  2019-04-15 14:51:30
# 4       100                   2297      True  2019-04-15 15:30:22
#
#           ResponseId  RecipientLastName  ...              Q25_9  \
# 0  R_1gwGnCDFBaVjcBF                NaN  ...  Strongly disagree
# 1  R_22Y3oGDhHHE1KfS                NaN  ...     Somewhat agree
# 2  R_1n3Mf5A1yQDFg5S                NaN  ...     Strongly agree
# 3  R_pPNzi5xgQe58wvf                NaN  ...          Undecided
# 4  R_25ydjEgaFStnwSM                NaN  ...          Undecided
#
#               Q25_10                                                Q26  \
# 0  Somewhat disagree                                                  a
# 1     Somewhat agree  This time, it was nice to feel confident in my...
# 2     Strongly agree                                                NaN
# 3          Undecided  It has made me more aware of how I respond whe...
# 4          Undecided  The chance to have uncomfortable teaching expe...
#
#                                                  Q27  \
# 0                                                  a
# 1  I appreciate having more control over what I w...
# 2                       Timing of simulator sessions
# 3                                                NaN
# 4  The simulator experience always felt very diff...
#
#                              Q28 Q34 Q35_1 Q36_1  Q37  Q38
# 0                              a  No   NaN   NaN  NaN  NaN
# 1  I personally am not concerned  No   NaN   NaN  NaN  NaN
# 2                            NaN  No   NaN   NaN  NaN  NaN
# 3                            NaN  No   NaN   NaN  NaN  NaN
# 4                           None  No   NaN   NaN  NaN  NaN
#
# [5 rows x 71 columns]

# %%
#clean the data for 2d 
data_2d=clean_survey_data(data_2d)
data_2d
# Out:
# C:\Users\15182\Documents\MSDS\MSDS_SERA_capstone\cleaning\utils.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   email_fix['email']=email_fix['email'].apply(lambda x:fix_email_add(x))
#                   email  sim_fbsk  \
# 1   hnj2gq@virginia.edu       6.0
# 2   wmn6kc@virginia.edu       9.0
# 3   zrh3aq@virginia.edu       6.0
# 4   bab7rr@virginia.edu       8.0
# 5   wwb4ka@virginia.edu       8.0
# ..                  ...       ...
# 75   hlh9j@virginia.edu       7.0
# 76  ekh2wb@virginia.edu       8.0
# 77  oce7ph@virginia.edu       7.0
# 78   rb2rf@virginia.edu       5.0
# 79  esw4au@virginia.edu       7.0
#
#                                                affect  q39  sim_cmsk  \
# 1   My feedback was more akin to positive reinforc...  NaN       7.0
# 2   I asked students to provide text evidence and ...  NaN       8.0
# 3   I felt a little scatter-brained today and I th...  NaN       9.0
# 4   Students seemed  to identify good answers to t...  NaN       7.0
# 5   '- We started to delve into the reasons why Li...  NaN       8.0
# ..                                                ...  ...       ...
# 75  Had students refer back to the text to find an...  NaN       6.0
# 76  '-did a good job of connecting individual stud...  NaN       7.0
# 77  I directed students to find textual evidence.\...  NaN       8.0
# 78  I gave them feedback on what I liked that they...  NaN       4.0
# 79  the students did a really good job at pulling ...  NaN       7.0
#
#                                                 score  \
# 1   My classroom helped us continue forward with t...
# 2   I heard from multiple students about their ide...
# 3   Everyone was able to participate in the discus...
# 4   Students identified several (I think 3) norms;...
# 5   '- Ethan was fairly on point, and not a major ...
# ..                                                ...
# 75  Students thought of three rules and had reason...
# 76  '-modeling a classroom norm example before giv...
# 77  I set expectations of taking turns to talk so ...
# 78  I think the expectations we were setting were ...
# 79  Everyone spoke, but the students who contribut...
#
#                                             rationale  \
# 1   Ethan exhibited disruptive behavior such as hu...
# 2   Some distraction, inattentiveness. Spoke out o...
# 3   '-Fidgeting\n-Attention seeking\n-Difficulty c...
# 4                  Off-task and distracting to others
# 5   Not to bad.  He was fairly on target throughou...
# ..                                                ...
# 75                          Distractable, high energy
# 76               '-distracted\n-sidetracked\n-fidgety
# 77                           distracted \ndisengaged
# 78  He wasn't really misbehaving, he was just bore...
# 79    A little distracted, but willing to participate
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 1   Ethan may be hyperactive on some level and  si...      Very much
# 2   Possibly LD. I would need access to IEP, 504, ...  Just a little
# 3          He may have an attention deficit disorder.      Very much
# 4   Many things might contribute to his behavior, ...    Pretty much
# 5                                            Boredom.  Just a little
# ..                                                ...            ...
# 75  He is a high energy student that would benefit...      Very much
# 76  '-not being comfortable in this setting/with t...  Just a little
# 77  He could be distracted by other students behav...    Pretty much
# 78  I would like to know how this student copes wi...  Just a little
# 79  He expressed his excitement to talk about what...    Pretty much
#
#       beh_humming  ... app_confer_stu_rc app_confer_parent_rc  \
# 1       Very much  ...               1.0                  1.0
# 2     Pretty much  ...               1.0                  4.0
# 3       Very much  ...               1.0                  1.0
# 4       Very much  ...               3.0                  3.0
# 5     Pretty much  ...               5.0                  8.0
# ..            ...  ...               ...                  ...
# 75      Very much  ...               4.0                  7.0
# 76      Very much  ...               1.0                  2.0
# 77      Very much  ...               1.0                  1.0
# 78    Pretty much  ...               1.0                  1.0
# 79  Just a little  ...               3.0                  6.0
#
#    app_behavior_plan_rc app_challenge_work_rc app_spend_time_rc  \
# 1                   1.0                   4.0               1.0
# 2                   7.0                  10.0               1.0
# 3                   2.0                   6.0               4.0
# 4                   4.0                   5.0               4.0
# 5                   6.0                   4.0               5.0
# ..                  ...                   ...               ...
# 75                  3.0                   9.0               8.0
# 76                  1.0                   6.0               3.0
# 77                  1.0                   5.0               1.0
# 78                  1.0                   4.0               3.0
# 79                  2.0                   6.0               5.0
#
#    app_space_regroup_rc app_beh_manage_coach_rc app_beh_manage_teach_rc  \
# 1                   3.0                     1.0                     1.0
# 2                   6.0                     5.0                     3.0
# 3                   7.0                     4.0                     3.0
# 4                   5.0                     4.0                     3.0
# 5                   7.0                     6.0                     4.0
# ..                  ...                     ...                     ...
# 75                  5.0                     7.0                     9.0
# 76                  1.0                     4.0                     3.0
# 77                  5.0                     1.0                     3.0
# 78                  3.0                     4.0                     9.0
# 79                  3.0                     7.0                     2.0
#
#    manage_app_negative manage_app_positive
# 1                  5.2               9.375
# 2                  2.6               6.375
# 3                  3.6               7.500
# 4                  7.4               7.125
# 5                  1.8               5.375
# ..                 ...                 ...
# 75                 1.8               4.500
# 76                 5.2               8.375
# 77                 2.6               8.750
# 78                 3.4               7.750
# 79                 3.2               6.750
#
# [78 rows x 72 columns]

# %%
#append four datasets
full=data_2a.append(data_2b)
full=full.append(data_2c)
full=full.append(data_2d)
full
# Out:
#                   email  sim_fbsk  \
# 0   ajm8gx@virginia.edu      10.0
# 1   alh8pk@virginia.edu       5.0
# 2    alp7q@virginia.edu       5.0
# 3   art2vr@virginia.edu       6.0
# 4   bab7rr@virginia.edu       8.0
# ..                  ...       ...
# 75   hlh9j@virginia.edu       7.0
# 76  ekh2wb@virginia.edu       8.0
# 77  oce7ph@virginia.edu       7.0
# 78   rb2rf@virginia.edu       5.0
# 79  esw4au@virginia.edu       7.0
#
#                                                affect  sim_cmsk  \
# 0   '-I think that delving into the background of ...      10.0
# 1   They seemed to have a good grasp on what made ...       NaN
# 2   '- I thought I did okay with going from questi...       2.0
# 3   I honestly was more concerned with making sure...       7.0
# 4   The students were on-task and seemed intereste...       4.0
# ..                                                ...       ...
# 75  Had students refer back to the text to find an...       6.0
# 76  '-did a good job of connecting individual stud...       7.0
# 77  I directed students to find textual evidence.\...       8.0
# 78  I gave them feedback on what I liked that they...       4.0
# 79  the students did a really good job at pulling ...       7.0
#
#                                                 score  \
# 0   '-In disciplining Ethan I was able to make sur...
# 1   I couldn't get to the discussion about class n...
# 2   I had a brief moment of success when Savannah ...
# 3   I think I did a good job on this. I asked the ...
# 4   The class provided one class expectation (to b...
# ..                                                ...
# 75  Students thought of three rules and had reason...
# 76  '-modeling a classroom norm example before giv...
# 77  I set expectations of taking turns to talk so ...
# 78  I think the expectations we were setting were ...
# 79  Everyone spoke, but the students who contribut...
#
#                                             rationale  \
# 0   Ethan was off-task often.\nHe interrupted othe...
# 1   Ethan was very distracted, full of energy, and...
# 2   He was disruptive but occasionally responsive ...
# 3   Super distracting. Every time I thought he was...
# 4   In this situation, Ethan was very off-task and...
# ..                                                ...
# 75                          Distractable, high energy
# 76               '-distracted\n-sidetracked\n-fidgety
# 77                           distracted \ndisengaged
# 78  He wasn't really misbehaving, he was just bore...
# 79    A little distracted, but willing to participate
#
#                                sim_txt_eth_contribute  beh_fidgeting  \
# 0   He may have ADD or another IEP. He may have a ...      Very much
# 1   He may have a short attention span, possibly A...      Very much
# 2   I'd want to know if there was a reason why he ...      Very much
# 3   I think the guidance counselor and parent/guar...  Just a little
# 4   A real student may act this way in class becau...    Pretty much
# ..                                                ...            ...
# 75  He is a high energy student that would benefit...      Very much
# 76  '-not being comfortable in this setting/with t...  Just a little
# 77  He could be distracted by other students behav...    Pretty much
# 78  I would like to know how this student copes wi...  Just a little
# 79  He expressed his excitement to talk about what...    Pretty much
#
#       beh_humming  beh_excitable  ... app_beh_manage_coach_rc  \
# 0       Very much      Very much  ...                     1.0
# 1       Very much    Pretty much  ...                     2.0
# 2       Very much  Just a little  ...                     1.0
# 3       Very much    Pretty much  ...                     1.0
# 4       Very much      Very much  ...                     7.0
# ..            ...            ...  ...                     ...
# 75      Very much    Pretty much  ...                     7.0
# 76      Very much  Just a little  ...                     4.0
# 77      Very much  Just a little  ...                     1.0
# 78    Pretty much     Not at all  ...                     4.0
# 79  Just a little  Just a little  ...                     7.0
#
#    app_beh_manage_teach_rc manage_app_negative manage_app_positive q39  q34  \
# 0                      1.0                 8.2               9.375 NaN  NaN
# 1                      1.0                 5.0               8.375 NaN  NaN
# 2                      1.0                 6.4               8.125 NaN  NaN
# 3                      1.0                 5.2               8.500 NaN  NaN
# 4                      4.0                 5.4               5.750 NaN  NaN
# ..                     ...                 ...                 ...  ..  ...
# 75                     9.0                 1.8               4.500 NaN   No
# 76                     3.0                 5.2               8.375 NaN   No
# 77                     3.0                 2.6               8.750 NaN   No
# 78                     9.0                 3.4               7.750 NaN  Yes
# 79                     2.0                 3.2               6.750 NaN   No
#
#    q35_1 q36_1  q37  q38
# 0    NaN   NaN  NaN  NaN
# 1    NaN   NaN  NaN  NaN
# 2    NaN   NaN  NaN  NaN
# 3    NaN   NaN  NaN  NaN
# 4    NaN   NaN  NaN  NaN
# ..   ...   ...  ...  ...
# 75   NaN   NaN  NaN  NaN
# 76   NaN   NaN  NaN  NaN
# 77   NaN   NaN  NaN  NaN
# 78   1.0   1.0   No  NaN
# 79   NaN   NaN  NaN  NaN
#
# [292 rows x 72 columns]

# %%
#reset index
full.reset_index(inplace=True)
full=full.drop(columns=['index'])

# %%
exit_emails=["bsd7cv@virginia.edu","bh4fk@virginia.edu","alh8pk@virginia.edu","ahm4kv@virginia.edu"]
for email in exit_emails:
    i = full[((full.email == email))].index
    full=full.drop(i)

# %%
#full=full.drop(columns=['index'])
full
# Out:
#                    email  sim_fbsk  \
# 0    ajm8gx@virginia.edu      10.0
# 2     alp7q@virginia.edu       5.0
# 3    art2vr@virginia.edu       6.0
# 4    bab7rr@virginia.edu       8.0
# 5    bbp5rr@virginia.edu       6.0
# ..                   ...       ...
# 287   hlh9j@virginia.edu       7.0
# 288  ekh2wb@virginia.edu       8.0
# 289  oce7ph@virginia.edu       7.0
# 290   rb2rf@virginia.edu       5.0
# 291  esw4au@virginia.edu       7.0
#
#                                                 affect  sim_cmsk  \
# 0    '-I think that delving into the background of ...      10.0
# 2    '- I thought I did okay with going from questi...       2.0
# 3    I honestly was more concerned with making sure...       7.0
# 4    The students were on-task and seemed intereste...       4.0
# 5    I think I definitely helped them talk and thin...       6.0
# ..                                                 ...       ...
# 287  Had students refer back to the text to find an...       6.0
# 288  '-did a good job of connecting individual stud...       7.0
# 289  I directed students to find textual evidence.\...       8.0
# 290  I gave them feedback on what I liked that they...       4.0
# 291  the students did a really good job at pulling ...       7.0
#
#                                                  score  \
# 0    '-In disciplining Ethan I was able to make sur...
# 2    I had a brief moment of success when Savannah ...
# 3    I think I did a good job on this. I asked the ...
# 4    The class provided one class expectation (to b...
# 5    I thought I did a good job of managing to get ...
# ..                                                 ...
# 287  Students thought of three rules and had reason...
# 288  '-modeling a classroom norm example before giv...
# 289  I set expectations of taking turns to talk so ...
# 290  I think the expectations we were setting were ...
# 291  Everyone spoke, but the students who contribut...
#
#                                              rationale  \
# 0    Ethan was off-task often.\nHe interrupted othe...
# 2    He was disruptive but occasionally responsive ...
# 3    Super distracting. Every time I thought he was...
# 4    In this situation, Ethan was very off-task and...
# 5    Ethan wanted to do his own thing, and was in h...
# ..                                                 ...
# 287                          Distractable, high energy
# 288               '-distracted\n-sidetracked\n-fidgety
# 289                           distracted \ndisengaged
# 290  He wasn't really misbehaving, he was just bore...
# 291    A little distracted, but willing to participate
#
#                                 sim_txt_eth_contribute  beh_fidgeting  \
# 0    He may have ADD or another IEP. He may have a ...      Very much
# 2    I'd want to know if there was a reason why he ...      Very much
# 3    I think the guidance counselor and parent/guar...  Just a little
# 4    A real student may act this way in class becau...    Pretty much
# 5    Possible attention deficit disorders.\nEasily ...    Pretty much
# ..                                                 ...            ...
# 287  He is a high energy student that would benefit...      Very much
# 288  '-not being comfortable in this setting/with t...  Just a little
# 289  He could be distracted by other students behav...    Pretty much
# 290  I would like to know how this student copes wi...  Just a little
# 291  He expressed his excitement to talk about what...    Pretty much
#
#        beh_humming  beh_excitable  ... app_beh_manage_coach_rc  \
# 0        Very much      Very much  ...                     1.0
# 2        Very much  Just a little  ...                     1.0
# 3        Very much    Pretty much  ...                     1.0
# 4        Very much      Very much  ...                     7.0
# 5    Just a little  Just a little  ...                     6.0
# ..             ...            ...  ...                     ...
# 287      Very much    Pretty much  ...                     7.0
# 288      Very much  Just a little  ...                     4.0
# 289      Very much  Just a little  ...                     1.0
# 290    Pretty much     Not at all  ...                     4.0
# 291  Just a little  Just a little  ...                     7.0
#
#     app_beh_manage_teach_rc manage_app_negative manage_app_positive q39  q34  \
# 0                       1.0                 8.2               9.375 NaN  NaN
# 2                       1.0                 6.4               8.125 NaN  NaN
# 3                       1.0                 5.2               8.500 NaN  NaN
# 4                       4.0                 5.4               5.750 NaN  NaN
# 5                       3.0                 3.0               6.625 NaN  NaN
# ..                      ...                 ...                 ...  ..  ...
# 287                     9.0                 1.8               4.500 NaN   No
# 288                     3.0                 5.2               8.375 NaN   No
# 289                     3.0                 2.6               8.750 NaN   No
# 290                     9.0                 3.4               7.750 NaN  Yes
# 291                     2.0                 3.2               6.750 NaN   No
#
#     q35_1 q36_1  q37  q38
# 0     NaN   NaN  NaN  NaN
# 2     NaN   NaN  NaN  NaN
# 3     NaN   NaN  NaN  NaN
# 4     NaN   NaN  NaN  NaN
# 5     NaN   NaN  NaN  NaN
# ..    ...   ...  ...  ...
# 287   NaN   NaN  NaN  NaN
# 288   NaN   NaN  NaN  NaN
# 289   NaN   NaN  NaN  NaN
# 290   1.0   1.0   No  NaN
# 291   NaN   NaN  NaN  NaN
#
# [287 rows x 72 columns]

# %%
#Merging with randomization information
randomization=pd.read_stata("../data/SimTeacher_Randomization_Complete_Fall2018_Spring2019.dta")
randomization
# Out:
#       id  sis_id                email                        name     program  \
# 0     67   ab2dx   ab2dx@virginia.edu                 Basile,Anna  elementary
# 1     86   ac4ah   ac4ah@virginia.edu              Copley,Abigail  elementary
# 2    108   ac5tp   ac5tp@virginia.edu            Cernev,Ana-Maria   secondary
# 3     76  aes5bq  aes5bq@virginia.edu  Shields, Allison Elizabeth  elementary
# 4     14  ajm8gx  ajm8gx@virginia.edu         Madison,Andrew John   secondary
# ..   ...     ...                  ...                         ...         ...
# 111  115  tdb5bd  tdb5bd@virginia.edu    Burmeister,Trenton David   secondary
# 112   26  wmn6kc  wmn6kc@virginia.edu       Neff,William Marshall   secondary
# 113   29  wwb4ka  wwb4ka@virginia.edu     Barnett,Walton Whelchel   secondary
# 114   28   yk5kb   yk5kb@virginia.edu                   Kim,Yewon   secondary
# 115   25  zrh3aq  zrh3aq@virginia.edu             Heard,Zora Ruby   secondary
#
#      section     strata    rannum  temp  numofstudents  tr_n  ra  \
# 0     Monday   Elem Mon  0.282820    11             39    10  CW
# 1    Tuesday  Elem Tues  0.016961     1             36     9  CB
# 2        old    Sec Old  0.225167     3             12     3  CB
# 3     Monday   Elem Mon  0.663871    23             39    10  TB
# 4        new    Sec New  0.643740    20             33     8  TB
# ..       ...        ...       ...   ...            ...   ...  ..
# 111      old    Sec Old  0.680040    11             12     3  TW
# 112      new    Sec New  0.924441    29             33     8  TW
# 113      new    Sec New  0.617195    19             33     8  TB
# 114      new    Sec New  0.958017    33             33     8  TW
# 115      new    Sec New  0.450501    15             33     8  CW
#
#     fall2018coachingra fall2018racera     fall2018coachingnotes  \
# 0          No Coaching          White  No coaching conversation
# 1          No Coaching          Black  No coaching conversation
# 2          No Coaching          Black  No coaching conversation
# 3             Coaching          Black     Coaching conversation
# 4             Coaching          Black     Coaching conversation
# ..                 ...            ...                       ...
# 111           Coaching          White     Coaching conversation
# 112           Coaching          White     Coaching conversation
# 113           Coaching          Black     Coaching conversation
# 114           Coaching          White     Coaching conversation
# 115        No Coaching          White  No coaching conversation
#
#     spring2019coachingra spring2019racera spring2019_ethan_original  \
# 0            No Coaching            Black                     Black
# 1            No Coaching            Black                     Black
# 2               Coaching            Black                     Black
# 3            No Coaching            White                     White
# 4            No Coaching            Black                     Black
# ..                   ...              ...                       ...
# 111          No Coaching            White                     White
# 112          No Coaching            White                     White
# 113          No Coaching            White                     White
# 114          No Coaching            White                     White
# 115             Coaching            White                     White
#
#     spring2019_coaching_original
# 0                    No Coaching
# 1                    No Coaching
# 2                       Coaching
# 3                    No Coaching
# 4                       Coaching
# ..                           ...
# 111                  No Coaching
# 112                     Coaching
# 113                  No Coaching
# 114                     Coaching
# 115                  No Coaching
#
# [116 rows x 19 columns]

# %%
full=full.merge(randomization,on='email',how='inner')
full
# Out:
#                    email  sim_fbsk  \
# 0    ajm8gx@virginia.edu      10.0
# 1    ajm8gx@virginia.edu       NaN
# 2     alp7q@virginia.edu       5.0
# 3     alp7q@virginia.edu       NaN
# 4     alp7q@virginia.edu       8.0
# ..                   ...       ...
# 281  rhh2hd@virginia.edu       8.0
# 282  hcg4gu@virginia.edu       5.0
# 283  hcg4gu@virginia.edu       NaN
# 284  hcg4gu@virginia.edu       7.0
# 285  seb5eg@virginia.edu       NaN
#
#                                                 affect  sim_cmsk  \
# 0    '-I think that delving into the background of ...      10.0
# 1                                                  NaN       7.0
# 2    '- I thought I did okay with going from questi...       2.0
# 3                                                  NaN       5.0
# 4    '- I think I was able to get the students to l...       9.0
# ..                                                 ...       ...
# 281  1. Asking students to provide evidence. \n2. H...       7.0
# 282  I tried to encourage further thought processes...       2.0
# 283                                                NaN       2.0
# 284  I got to give feedback to all of the  students...       2.0
# 285                                                NaN       3.0
#
#                                                  score  \
# 0    '-In disciplining Ethan I was able to make sur...
# 1    '-I maintained a strong voice throughout the e...
# 2    I had a brief moment of success when Savannah ...
# 3    I tried to redirect the behavior of Ethan and ...
# 4    '- I was successful in getting the students to...
# ..                                                 ...
# 281  1. Having students be involved in expectation ...
# 282  I am not familiar with classroom management ye...
# 283  I really struggled to support student engageme...
# 284  I have done this  simulation  before but it re...
# 285  '- classroom management was weak when it came ...
#
#                                              rationale  \
# 0    Ethan was off-task often.\nHe interrupted othe...
# 1    '-Consistently off task\n-He may have an IEP o...
# 2    He was disruptive but occasionally responsive ...
# 3    Humming \ntalking about off topic things \ntal...
# 4    He was responsive to me when I asked him to st...
# ..                                                 ...
# 281                           '-talkative\n-disruptive
# 282              Disruptive, class clown type behavior
# 283  Very disruptive and loud\nMade it very difficu...
# 284       Loud, unresponsive, disruptive, unempathetic
# 285  poor\n- he was distracted\n- he was not on tas...
#
#                                 sim_txt_eth_contribute  beh_fidgeting  \
# 0    He may have ADD or another IEP. He may have a ...      Very much
# 1    '-He may have been trying to impress his peers...      Very much
# 2    I'd want to know if there was a reason why he ...      Very much
# 3    I would want to know Ethan better and consider...    Pretty much
# 4    I would probably check whether he received SPE...  Just a little
# ..                                                 ...            ...
# 281  '- How can I help him? \n- Having a discussion...    Pretty much
# 282  He seems to have a lot of energy and difficult...    Pretty much
# 283  I would like to know about his background and ...    Pretty much
# 284  I would love to know about his background  and...    Pretty much
# 285  things that contribute to his behavior\n- elec...  Just a little
#
#        beh_humming  beh_excitable  ... numofstudents tr_n  ra  \
# 0        Very much      Very much  ...            33    8  TB
# 1      Pretty much      Very much  ...            33    8  TB
# 2        Very much  Just a little  ...            33    8  CB
# 3        Very much      Very much  ...            33    8  CB
# 4    Just a little  Just a little  ...            33    8  CB
# ..             ...            ...  ...           ...  ...  ..
# 281    Pretty much    Pretty much  ...            12    3  TB
# 282      Very much    Pretty much  ...            39   10  CB
# 283      Very much      Very much  ...            39   10  CB
# 284      Very much      Very much  ...            39   10  CB
# 285      Very much    Pretty much  ...            12    3  TW
#
#     fall2018coachingra fall2018racera     fall2018coachingnotes  \
# 0             Coaching          Black     Coaching conversation
# 1             Coaching          Black     Coaching conversation
# 2          No Coaching          Black  No coaching conversation
# 3          No Coaching          Black  No coaching conversation
# 4          No Coaching          Black  No coaching conversation
# ..                 ...            ...                       ...
# 281           Coaching          Black     Coaching conversation
# 282        No Coaching          Black  No coaching conversation
# 283        No Coaching          Black  No coaching conversation
# 284        No Coaching          Black  No coaching conversation
# 285           Coaching          White                  No notes
#
#     spring2019coachingra spring2019racera spring2019_ethan_original  \
# 0            No Coaching            Black                     Black
# 1            No Coaching            Black                     Black
# 2               Coaching            Black                     Black
# 3               Coaching            Black                     Black
# 4               Coaching            Black                     Black
# ..                   ...              ...                       ...
# 281          No Coaching            Black                     Black
# 282          No Coaching            Black                     Black
# 283          No Coaching            Black                     Black
# 284          No Coaching            Black                     Black
# 285          No Coaching            White                     White
#
#     spring2019_coaching_original
# 0                       Coaching
# 1                       Coaching
# 2                    No Coaching
# 3                    No Coaching
# 4                    No Coaching
# ..                           ...
# 281                     Coaching
# 282                  No Coaching
# 283                  No Coaching
# 284                  No Coaching
# 285                     Coaching
#
# [286 rows x 90 columns]

# %%
#Merging with CPP covariate data
